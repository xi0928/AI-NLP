# %% [markdown]
# ## Lesson-01 Assignment

# %% [markdown]
# >

# %% [markdown]
# `各位同学大家好，欢迎各位开始学习我们的人工智能课程。这门课程假设大家不具备机器学习和人工智能的知识，但是希望大家具备初级的Python编程能力。根据往期同学的实际反馈，我们课程的完结之后 能力能够超过80%的计算机人工智能/深度学习方向的硕士生的能力。`

# %% [markdown]
# ## 本次作业的内容

# %%
#### 1. 复现课堂代码
simple_grammar = """
sentence => noun_phrase verb_phrase
noun_phrase => Article Adj* noun
Adj* => null | Adj Adj*
verb_phrase => verb noun_phrase
Article =>  一个 | 这个
noun =>   女人 |  篮球 | 桌子 | 小猫
verb => 看着   |  坐在 |  听着 | 看见
Adj =>  蓝色的 | 好看的 | 小小的
"""

# %% [raw]
# # 定义一个grammar函数，表示Grammar的语法结构
# def create_grammar(grammar_str, split='=>', line_split='\n'):
#     grammar = {}
#     for line in grammar_str.split(line_split):
#         if not line.strip(): continue
#         exp, stmt = line.split(split)
#         grammar[exp.strip()] = [s.split() for s in stmt.split('|')]
#     return grammar

# %% [raw]
# # 定义一个generate函数
# import random
# choice = random.choice
#
# def generate(gram, target):
#     if target not in gram: return target # means target is a terminal expression，终止符
#
#     expaned = [generate(gram, t) for t in choice(gram[target])] #将非终止的target扩展
#     return ''.join([e if e != '/n' else '\n' for e in expaned if e != 'null']) #合并，舍去 null

# %%
example_grammar = create_grammar(simple_grammar)

# %%
generate(gram=example_grammar, target='sentence')

# %%
#在西部世界里，一个”人类“的语言可以定义为：

human = """
human = 自己 寻找 活动
自己 = 我 | 俺 | 我们 
寻找 = 找找 | 想找点 
活动 = 乐子 | 玩的
"""


#一个“接待员”的语言可以定义为

host = """
host = 寒暄 报数 询问 业务相关 结尾 
报数 = 我是 数字 号 ,
数字 = 单个数字 | 数字 单个数字 
单个数字 = 1 | 2 | 3 | 4 | 5 | 6 | 7 | 8 | 9 
寒暄 = 称谓 打招呼 | 打招呼
称谓 = 人称 ,
人称 = 先生 | 女士 | 小朋友
打招呼 = 你好 | 您好 
询问 = 请问你要 | 您需要
业务相关 = 玩玩 具体业务
玩玩 = null
具体业务 = 喝酒 | 打牌 | 打猎 | 赌博
结尾 = 吗？
"""

# %%
for i in range(20):
    print(generate(gram=create_grammar(host, split='='), target='host'))

# %%
import pandas as pd

# %%
import re

# %%
import jieba

# %%
filename = '/Users/HP/Downloads/sqlResult_1558435.csv'

# %%
content = pd.read_csv(filename, encoding='gb18030')

# %%
articles = content['content'].tolist()

# %%
def token(string):
    return re.findall('\w+', string)

# %%
articles_clean = [''.join(token(str(a)))for a in articles]

# %%
with open('article_9k.txt', 'w') as f:
    for a in articles_clean:
        f.write(a + '\n')

# %%
def cut(string): 
    return list(jieba.cut(string))

# %%
TOKEN = []

# %%
for i, line in enumerate((open('article_9k.txt'))):
    if i % 100 == 0: print(i)  
    TOKEN += cut(line)

# %%
from collections import Counter

# %%
words_count = Counter(TOKEN)

# %%
def prob_1(word):
    return words_count[word] / len(TOKEN)

# %%
TOKEN = [str(t) for t in TOKEN]

# %%
TOKEN_2_GRAM = [''.join(TOKEN[i:i+2]) for i in range(len(TOKEN[:-2]))]

# %%
words_count_2 = Counter(TOKEN_2_GRAM)

# %% [raw]
# def prob_2(word1, word2):
#     if word1 + word2 in words_count_2: return words_count_2[word1+word2] / len(TOKEN_2_GRAM)
#     else:
#         return 1 / len(TOKEN_2_GRAM)

# %%
prob_1("知道")

# %%
prob_2("我们", "知道")

# %%
def get_probablity(sentence):
    words = cut(sentence)
    
    sentence_pro = 1
    
    for i, word in enumerate(words[:-1]):
        next_ = words[i+1]
        
        probability = prob_2(word, next_)
        
        sentence_pro *= probability
    
    return sentence_pro

# %%
for sen in [generate(gram=example_grammar, target='sentence') for i in range(10)]:
    print('sentence: {} with Prb: {}'.format(sen, get_probablity(sen)))

# %%
need_compared = [
    "今天中午吃啥饭，我们一起吃日本 下午你去干什么，我们一起吃苹果",
    "真是一头的大包 真时一只好看的笑猫",
    "今晚我去吃火锅 今晚苹果来吃我",
    "服务员可乐来一杯 大小姐来一箱白开水"
    ]

for s in need_compared:
    s1, s2 = s.split()
    p1, p2 = get_probablity(s1), get_probablity(s2)
    
    better = s1 if p1 > p2 else s2
    
    print('{} is more possible'.format(better))
    print('-'*4 + ' {} with probility {}'.format(s1, p1))
    print('-'*4 + ' {} with probility {}'.format(s2, p2))

# %% [markdown]
# #### 2. 请回答以下问题
#
# 回答以下问题，并将问题发送至 mqgao@kaikeba.com中：
# ```
#     2.1. what do you want to acquire in this course？
#     2.2. what problems do you want to solve？
#     2.3. what’s the advantages you have to finish you goal?
#     2.4. what’s the disadvantages you need to overcome to finish you goal?
#     2.5. How will you plan to study in this course period?
# ```

# %% [markdown]
# #### 3. 如何提交
# 代码 + 此 jupyter 相关，提交至自己的 github 中(**所以请务必把GitHub按照班主任要求录入在Trello中**)；
# 第2问，请提交至mqgao@kaikeba.com邮箱。
# #### 4. 作业截止时间
# 此次作业截止时间为 2019.7.6日

# %% [markdown]
# #### 5. 完成以下问答和编程练习

# %% [markdown]
# >

# %% [markdown]
# ## 基础理论部分

# %% [markdown]
# #### 0. Can you come up out 3 sceneraies which use AI methods?

# %% [raw]
# Ans: 语音识别 自动驾驶 决策

# %% [markdown]
# #### 1. How do we use Github; Why do we use Jupyter and Pycharm;

# %% [raw]
# Ans: Github has many functions,which incloud of git clone/git add/git pull/git push/git commit.We can use git clone to clone other repo,and use git add to add the file to the origin master,aslo use git pull to pull the last vertion of the repo you need, git push means push the file to the repo and git commit means give a commit to the file you add to the repo.
# We use Jupyter because Jupyter is convenient for display and it can edit mathematical formulas.
# We use Pycharm because it's a full-featured integrated development environment.

# %% [markdown]
# #### 2. What's the Probability Model?

# %% [raw]
# Ans: 概率模型是指多个变量相互影响时，其联合概率为各变量间的条件概率相乘

# %% [markdown]
# #### 3. Can you came up with some sceneraies at which we could use Probability Model?

# %% [raw]
# Ans: 预测天气/预测金融产品跌涨

# %% [markdown]
# #### 4. Why do we use probability and what's the difficult points for programming based on parsing and pattern match?

# %% [raw]
# Ans:基于统计学意义预测事情发生的可能性，比较准确。难点是变量过多时基于所有变量的条件概率难以实现。

# %% [markdown]
# #### 5. What's the Language Model;

# %% [raw]
# Ans:基于分词或词组的概率模型生成自然语言的模型

# %% [markdown]
# #### 6. Can you came up with some sceneraies at which we could use Language Model?

# %% [raw]
# Ans:自动分词/自动生成句子/识别句子要表达的褒贬义

# %% [markdown]
# #### 7. What's the 1-gram language model;

# %% [raw]
# Ans:分词相互独立，只统计出现的概率，不考虑条件概率

# %% [markdown]
# #### 8. What's the disadvantages and advantages of 1-gram language model;

# %% [raw]
# Ans:优点是可以简化计算，缺点是分词独立，句子生成不准确

# %% [markdown]
# #### 9. What't the 2-gram models;

# %% [raw]
# Ans:句子出现的某一分词只与其后面的那个分词相关，与其他分词无关，即某个句子的联合概率为相邻两个分词的条件概率相乘。

# %% [markdown]
# ## 编程实践部分

# %% [markdown]
# #### 1. 设计你自己的句子生成器

# %% [markdown]
# 如何生成句子是一个很经典的问题，从1940s开始，图灵提出机器智能的时候，就使用的是人类能不能流畅和计算机进行对话。和计算机对话的一个前提是，计算机能够生成语言。
#
# 计算机如何能生成语言是一个经典但是又很复杂的问题。 我们课程上为大家介绍的是一种基于规则（Rule Based）的生成方法。该方法虽然提出的时间早，但是现在依然在很多地方能够大显身手。值得说明的是，现在很多很实用的算法，都是很久之前提出的，例如，二分查找提出与1940s, Dijstra算法提出于1960s 等等。

# %% [markdown]
# 在著名的电视剧，电影《西部世界》中，这些机器人们语言生成的方法就是使用的SyntaxTree生成语言的方法。
#
# >
# >
#
# ![WstWorld](https://timgsa.baidu.com/timg?image&quality=80&size=b10000_10000&sec=1561818705&di=95ca9ff2ff37fcb88ae47b82c7079feb&src=http://s7.sinaimg.cn/mw690/006BKUGwzy75VK46FMi66&690)
#
# >
# >

# %% [markdown]
# 在这一部分，需要各位同学首先定义自己的语言。 大家可以先想一个应用场景，然后在这个场景下，定义语法。例如：
#
# 在西部世界里，一个”人类“的语言可以定义为：
# ```
# human = """
# human = 自己 寻找 活动
# 自己 = 我 | 俺 | 我们
# 寻找 = 看看 | 找找 | 想找点
# 活动 = 乐子 | 玩的
# """
# ```
#
# 一个“接待员”的语言可以定义为
# ```
# host = """
# host = 寒暄 报数 询问 业务相关 结尾
# 报数 = 我是 数字 号 ,
# 数字 = 单个数字 | 数字 单个数字
# 单个数字 = 1 | 2 | 3 | 4 | 5 | 6 | 7 | 8 | 9
# 寒暄 = 称谓 打招呼 | 打招呼
# 称谓 = 人称 ,
# 人称 = 先生 | 女士 | 小朋友
# 打招呼 = 你好 | 您好
# 询问 = 请问你要 | 您需要
# 业务相关 = 玩玩 具体业务
# 玩玩 = 耍一耍 | 玩一玩
# 具体业务 = 喝酒 | 打牌 | 打猎 | 赌博
# 结尾 = 吗？"""
#
# ```

# %% [markdown]
# 请定义你自己的语法:

# %% [markdown]
# 第一个语法：

# %%
daughter = '''
daughter = 称呼 自己 要 玩具
称呼 = 爸爸 | 妈妈 | 奶奶 | 姥姥
自己 = 我 | 宝宝 | 妮妮
要 = 想买 | 想要 | 好想买
玩具 = 芭比娃娃 | 小猪佩奇 | 毛绒小熊
'''

# %% [markdown]
# 第二个语法：

# %%
family_num  = '''
family_num = 称呼 短语 玩具 程度副词 名词 结尾
称呼 = 宝宝 | 妮妮
短语 = 你买的 | 你的
玩具 = 芭比娃娃 | 小猪佩奇 | 毛绒小熊
程度副词 = 程度副词 | 程度副词 程度副词 
程度副词 = 太 | 很
名词 = 多 | 不少
结尾 = 了啊 | 了啦 | 了哦 | 了呀
'''

# %% [markdown]
# TODO: 然后，使用自己之前定义的generate函数，使用此函数生成句子。

# %%
generate(gram=create_grammar(family_num, split='='), target='family_num')

# %% [markdown]
# TODO: 然后，定义一个函数，generate_n，将generate扩展，使其能够生成n个句子:

# %%
def generate_n(n):
    for i in range(n):
        gene_n= generate(gram=create_grammar(family_num, split='='), target='family_num')
        genera_n = gene_n + "\n"
        print(genera_n)

# %%
generate_n(10)

# %% [markdown]
# >

# %% [markdown]
# #### 2. 使用新数据源完成语言模型的训练

# %% [markdown]
# 按照我们上文中定义的`prob_2`函数，我们更换一个文本数据源，获得新的Language Model:
#
# 1. 下载文本数据集（你可以在以下数据集中任选一个，也可以两个都使用）
#     + 可选数据集1，保险行业问询对话集： https://github.com/Computing-Intelligence/insuranceqa-corpus-zh/raw/release/corpus/pool/train.txt.gz
#     + 可选数据集2：豆瓣评论数据集：https://github.com/Computing-Intelligence/datasource/raw/master/movie_comments.csv
# 2. 修改代码，获得新的**2-gram**语言模型
#     + 进行文本清洗，获得所有的纯文本
#     + 将这些文本进行切词
#     + 送入之前定义的语言模型中，判断文本的合理程度

# %%
filename = '/Users/HP/Downloads/movie_comments.csv'

# %%
import pandas as pd

# %%
import re

# %%
import jieba

# %%
with open(filename, encoding= "utf_8") as fil:
            content = pd.read_csv(fil)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (0,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
articles = content['comment'].tolist()

# %%
articles[1]
# Out:
# '首映礼看的。太恐怖了这个电影，不讲道理的，完全就是吴京在实现他这个小粉红的英雄梦。各种装备轮番上场，视物理逻辑于不顾，不得不说有钱真好，随意胡闹'

# %%
def token(string):
    return re.findall('\w+', string)

# %%
articles_clean = [''.join(token(str(a)))for a in articles]

# %%
articles_clean[8]
# Out:
# '开篇长镜头惊险大气引人入胜结合了水平不俗的快剪下实打实的真刀真枪让人不禁热血沸腾特别弹簧床架挡炸弹空手接碎玻璃弹匣割喉等帅得飞起就算前半段铺垫节奏散漫主角光环开太大等也不怕作为一个中国人两个小时弥漫着中国强大得不可侵犯的氛围还是让那颗民族自豪心砰砰砰跳个不停'

# %%
with open('article_mov.txt', 'w',encoding= "utf_8") as f:
    for a in articles_clean:
        f.write(a + '\n')

# %%
TOKEN = []

# %%
def cut(string): 
    return list(jieba.cut(string))

# %%
for i, line in enumerate((open('article_mov.txt',encoding= "utf_8"))):
    if i % 100 == 0:print(i,line)  
    TOKEN += cut(line)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\HP\AppData\Local\Temp\jieba.cache
# 0 吴京意淫到了脑残的地步看了恶心想吐
# Loading model cost 0.892 seconds.
# Prefix dict has been built succesfully.
# 100 wtf我为啥要看这个
#
# 200 当坚持不下去的时候再努力坚持一下
#
# 300 感人至深的电影
#
# 400 我觉得简直是校园青春片的一股清流不懂为什么那么多人给差评没有堕胎没有堕落吸烟只是简简单单的暗恋有什么不好吗都说日本青春片质量高情书里面在图书馆直接啪啪啪就符合你们的审美了
#
# 500 影片努力规避早恋却满屏暧昧
#
# 600 太基情了我不要还我明日香真希波玛丽凌波丽三女神音乐依旧好好听櫻流し宇多田ヒカル
#
# 700 真是浪费我钱
#
# 800 犯我中华者虽远必诛特种兵丛林战等军事专业细节让人看得血脉喷张但故事有瑕疵神马拆地雷刀子反戈老外踩着倪大宏边境吓退军队但士兵们蛮有个性牺牲时充斥血与泪幽默调戏女一狙击枪穿石爆头刺刀屠狼群扫倒大树救人吴京豁出去拼节奏紧凑简单粗暴坦克直升机客串难怪火
#
# 900 陆港合拍主旋律的高峰林超贤的重口黑帮戏拍法非常适合缉毒特警表现可惜国内戏的节奏和表演方式太像国产电视剧也提供不了快速剪辑的空间发挥余地不如国外部分结尾快艇戏变化少略拖最后总结中心思想坏胃口但真实案件改编还牵扯国际政治算是带着镣铐跳舞的佳作
#
# 1000 隔壁郭抄抄被黑出了屎这部主旋律被赞开了花一毁一誉间冰火两重天其实屎是撒了金粉喷了香水的屎花是只可远观不可细赏的塑料花都是假风景实则真平庸而最可玩味的还是这一众带情绪不带脑子的看客及其言行
#
# 1100 你们看看现在稍微正常点的国产片评分都给衬托的啥样了
#
# 1200 再庞大和离奇的交通工具也掩盖不住本系列行将就木的想象力和单薄无力的剧情速激系列在第七部达到高潮结束就好这之后只能越来越痿
#
# 1300 我给的分跟大家差这么多一定是我自己的问题
#
# 1400 武戏超赞音效超赞但剧情链接和细节就很想让人吐槽张晋看来以后片子会越来越多啦
#
# 1500 1张晋竟然被领带勒死2西装不够好道具组监制你们亏待了张晋3张晋的优雅体现的不够张晋你那么爱美你一定是受4吴京不再打打打人物细节处理得可以用上演技二字了5古天乐你简直太能演了6张晋你什么时候偷师你师妹的老猿挂印7蔡少芬果然会嫁人
#
# 1600 让你去抓蛤蟆真是屈才比悟空传的闹天庭和大护法的人吃人更具现实意义它即便有太多不足也足以让我在这个暑期档给它五颗星步步为营层层递进构出这个修罗战场甚至最后把格局完全打开剧本也没有崩坏极为难得最后一定要等到彩蛋丁修登场他当时第一次听到靳一川的名号
#
# 1700 服装造型是花了心思的电影节奏可以打戏也好看几个男性角色算出彩
#
# 1800 如果脱离超级英雄背景这就是一个杀手里昂般的故事另外不知道墨西哥孩子穿越边界一定要去加拿大这剧情是不是巧合没有十字只有X字再见狼叔
#
# 1900 不知道那些口口声声说人物没改变的人是怎么看的电影大概是爱看漫威导致看超英片习惯性不带大脑所以看dc也就同理了可惜写影评的时候却自动开启双标模式哗众取宠
#
# 2000 魂斗罗之漏洞在人
#
# 2100 还算紧凑两人表现都不错就事打斗场面不算激烈
#
# 2200 runrunrun
#
# 2300 看完后真的哭了男主一直想从监狱出出去对自由的那种渴望太让人震撼了
#
# 2400 学校看的看完感慨良多好电影
#
# 2500 非常完整的商业电影十分cute
#
# 2600 太勉强了从头到尾没有入戏这个故事的日本味道太浓厚了所以里面的西洋面孔看着违和感十足而且音乐几乎没断过这一点真的挺烦啊
#
# 2700 可不可以也有这么一个生命一直等着我
#
# 2800 Luckey
#
# 2900 一个人的电影
#
# 3000 毫不基情的友情片
#
# 3100 他们知道什么是人性懂得尊重别人有信仰普遍自由平等博爱人们可以追求他们想要的生活和梦想瓷国世态炎凉钱权至上毫无信仰只求吃喝表示早已看穿西方人权不过纸老虎耳89
#
# 3200 让人感动的片子对于内心存在恐惧的人来说这是最好的辅导片子记得那句吧忘记其他一切对着我说对着我这个朋友说这就是演讲的真谛
#
# 3300 音乐就是春雨飞扬
#
# 3400 我还想坐进影院再静静地听一遍结尾的歌
#
# 3500 马特戴蒙的硬照没法看本阿弗莱克真是帅啊其他的都还凑合吧BTW有些台词让我反省了一下自个儿
#
# 3600 毫无期待去看结果竟然不错嘻哈乐感觉的漫画夸张风除了把男高写成大学与男主性格出身不太符设定都还好青春荷尔蒙转为有理由的暴力才有意思几个日本演员的角色很有趣热血高校里的花瓶成了家族担当日满时期东北人与日本人都要面对身份疑问这是比抗日叙事之外的人性故事
#
# 3700 被向奕铮圈粉了有帅到好帅跟女主角好搭
#
# 3800 32星台词矫情蛋疼剧情推进靠旁白字幕作男作女女主圣母婊男主傻白甜天仙似乎圆润了一些吴亦凡双腿长出天际无奈只要一用力全场就笑如果老炮儿的吴亦凡打75分本片最多35虽不适合用力但吴蛮适合卖萌100分钟我有90分钟可以暂时忘记他泰迪精的事儿本片适合颜狗来看
#
# 3900 电影剪辑及叙述故事的方式不错故事本身一般
#
# 4000 今年犯了三百六十五个错误为了惩罚自己我决定自掏腰包去看小时代首映
#
# 4100 上午没看前很开心地打了三星看过后才知道错了本片演技浮夸情节杂乱三观不正远胜前两部已经彻底沦为一部连和闺蜜去吐槽嘲笑傻乐都不想看的影片若有一天也能在我国荧幕上看见如sunny那样的闺蜜片就好了唉
#
# 4200 郭敬明是个好导演
#
# 4300 竟然觉得还不错虽然感情线有点太顺了井宝和ab的cp简直虐死人
#
# 4400 郑恺貌似没演过啥好片吧此外这两个香港武术指导貌似又是来大陆圈钱的吧
#
# 4500 剪得乱七八糟莫名其妙的狗血装b烂片冲自掏看的毕竟曾经喜欢过看前对他的颜值没抱什么希望但一开场那身西装真的惊艳到我了wuli韬韬身材还是不错的
#
# 4600 一如既往地看不懂
#
# 4700 我一直看不懂eva可是一直很喜欢
#
# 4800 算是这个系列里剧情最饱满的一部了打斗场面也不错但我还是不能容忍TM装逼的话唠就算是空境的脑残粉也得承认你们其实是来看两仪式切水果的吧所以网络上会有空境的战斗剪辑版而永远不会有语录剪辑版你们一直在摁快进吧
#
# 4900 06年和09年的还都没看直接跳到10年剧场版的看也看的懂这里团长是跑龙套的角色我还是更喜欢yuki那个阿虚为什么就不选她呢虽然吧换了是我也会毫不犹豫的按enter这就叫双重标准片尾的清唱治愈催眠
#
# 5000 长门
#
# 5100 动漫果然还是要看日本的赞啊
#
# 5200 虽然没完全看懂
#
# 5300 我看的版本居然还是有码的
#
# 5400 3D效果貌似多了线条也粗了一些但是动作很生硬就像3D游戏刚出来的时候一样那场史诗大战蛮不错人物刻画也越来越丰满了相对于第一集除了画面流畅感其他都有进步看起来很像改编的水浒传哇音乐值得注意
#
# 5500 屎克威尔就是个妖啊这动画做的华丽
#
# 5600 没看懂配乐很中意
#
# 5700 合拍片最麻烦是不知道调哪个音轨好无论国粤都是被配掉的
#
# 5800 我觉得杰森斯坦森说话时看史泰龙的眼神不太对了呢逗比班德拉斯太棒
#
# 5900 片头赞赞的其他没了
#
# 6000 片尾音乐响起泪目怎么说的出再见特效赞
#
# 6100 臆想一下PaulWalker在车祸中离去大概是飙车吧就像在电影里与多姆驶上两条分别的马路看车辆消失在地平线记忆也留在那儿要是如同电影中那样40岁也不必嗟叹可惜他比80岁还要丰盈
#
# 6200 冲着最后那段二胡曲就给三星了
#
# 6300 13D效果好而且看见古战船和神都洛阳这些对我来说比阿凡达之类要更有亲切感更加激动2冯绍峰就是狄仁杰的白马王子啊各种意义上3金范怒打酱油怪物造型白瞎一张好脸4丁大人和太医都好萌5最后的几张设计图看的热血喷张千万要继续拍啊
#
# 6400 非常清晰的时间线吾先生在被华子摄像时爆发的张力十分震撼临死之前吾先生清唱的小丑听到心碎流泪结尾华子与母亲的道别再次让人飙泪小窦的搞笑为片子增添色彩王千源的演技完全是年度最佳
#
# 6500 豆瓣和IMDB上都这么高分逗我呢这是回头一看是漫画改编瞬间释然了闪光点是看Colin叔耍帅跳伞脑袋烟花和升级suitup版的小混混但是全片还是充满了脑洞太大WTF的剧情比如NickFury的诡异阴谋和Colin叔的百人斩黑色幽默不是这么玩儿的好么
#
# 6600 真心燃爆了IMAX看得浑身舒爽好笑紧张又炫酷配乐超级精彩爆头那段儿不多说了大家自行去体会科叔是天生衣架子刀锋女战士好霸气两只小特工也都不错JD为了剧情只是打了个酱油好伤心虽说男主一颗子弹都没挨上实在太扯但算了不纠结这个四刷完毕CBD万达卢米埃王府井耀莱
#
# 6700 在某些地方很有点水平但是主角在作案和行善动机上都莫名其妙完全没有说服力看完觉得一愣一愣的王珞丹演任何角色都是一副非常讨厌的傻逼模样
#
# 6800 真正的好片
#
# 6900 尽管西装和演技可圈可点但是反派实在不给力一上来张牙舞爪虚张声势结果却是纸老虎一戳即破不过瘾而且唯一的美女那么轻易就挂了不高兴
#
# 7000 怎么讲警匪片讲政治斗争也要按照基本法来一部所有人都不会笑不会像人一样说话的高级小时代加半颗星给文咏珊369度符合撸点with爽
#
# 7100 表演僵硬情节混乱节奏糟糕剧本就连日戏夜戏都没安排妥当这完全是造故事不是讲故事是做项目不是拍电影前几天在一篇访谈里看到宁浩自称为一个艺术家然后昨天又看到一篇软文说曹保平要做中国版诺兰最近还因为Narcos经常看到魔幻现实主义这个词一切都是那么的魔幻现实
#
# 7200 我是不懂为啥老拿环形叙事说事反正有风格就好看哪怕盖瑞奇和昆汀是我最喜欢的导演我也不觉得他们仨能弄出个连连看
#
# 7300 好看
#
# 7400 还是用爱感化的故事国语配音杀伤力太大了
#
# 7500 就是一心觉得MattDamon帅得不要不要的没别的嘿嘿
#
# 7600 384你过来我给你洗洗头
#
# 7700 为什么片尾激发冲突的导火索事件时间是苏联解体的1991年12月为什么象征美利坚之魂的美国队长拒绝签署联合国的监管协议为什么曾被苏联杀手雇佣的冬兵出自纳粹极权实验之手为什么来自第三世界的非洲君主黑豹假意站队实则中立因为是我想多了
#
# 7800 点映镜头表现力很强武戏利落文戏韵味一扫十二月初的电影圈雾霾宋佳很美
#
# 7900 迄今看到的味儿最正的武侠电影也是第一次为片中行云流水的武打动作所着迷漂亮干净一个真正通武学的导演一丝不紊道出武化而非空洞的武打少了一代宗师的晦涩写意除几处故作姿态武韵仍高深引思按规矩办事儿的徐浩峰已然是大陆武侠电影的曙光
#
# 8000 一曲忠诚的赞歌
#
# 8100 看完一代宗师我在心里说这才是电影为什么王家卫拍电影速度奇慢大概是因为他试图在每一秒的画面中都营造出高度风格化的诗意氛围他是造梦师他是时光雕刻家他是本雅明所说的那种灵韵艺术创造者只是在这个电影麦当劳化的时代他这么拍电影是不是太奢侈了
#
# 8200 第一次对美国队长有正面印象原来一直觉得他是个鸡肋人物看完以后感觉1各种美剧主演混搭跑进来了HIMYMRevenge主演2斯嘉丽好漂亮3塞巴斯蒂安好帅4开枪有强迫症只射盾牌不射腿233
#
# 8300 故事非常的紧凑作为一部动作片十分优秀PSFBI最开始派出的那个杀手长得像民工
#
# 8400 7582
#
# 8500 绅士密令比较好听啊哎盖导拉肚子的时候写的剧本嘛人物剧情好无聊啊更要命的是太多奇怪口音讲英语影响观感啊连配乐都不甚出彩会有第二部吗片尾做这么用心藏那么多细节干嘛啊casting有问题啊illya并不像是孔武有力暴力倾向的怪物啊
#
# 8600 最后高潮戏码一气呵成视觉上以小见大的效果更是非同凡响顺便教你托马斯小火车的正确使用方法
#
# 8700 热血与热泪齐飙毫无喘息的2小时节奏畅快无滞碍蒸汽朋克末世废土飞车枪战爆炸打斗公路革命救赎各种元素交织完美剪贞操裤一幕最为彰显女权精神据说幕后有女权顾问阴道独白的EveEnsler真的吗尽管一直聚焦于飞车枪战人物竟能个个立体饱满亦兼顾到动人感情线如何做到的
#
# 8800 打斗很爽快剧情带有此类剧中难得的宿命感
#
# 8900 胖子也是坏人
#
# 9000 整体不如一文戏过多过于文艺腔动作戏基本还是保持了上一部的水准开打之前比真打更还好看更有味道
#
# 9100 结果还是三个人的羁绊基情感觉没太大突破而且解释了太多很拖沓中间还像少了很多最后发现是删减了好多
#
# 9200 大部分时间都在汗毛倒竖脊背发凉最后从枪弹横飞的影院出来灰土飞扬的晚风吹起黑色的围巾黑色的头发没系扣子的大衣顿时觉得自己也杀气十足_
#
# 9300 是剪辑的问题吗怎么有些情节交代的不清不楚的看了讨论区的帖子笑死我了各色明星轮番客串好多人都没认出来就枪战戏来说在小学校门口好假
#
# 9400 绣春刀离佳作还有些距离主要是后半截问题比较突出比较潦草但是整体内容较为扎实完成度高观赏性也不错算是很值得鼓励的国产作品了在近期乌烟瘴气的电影院里终于吸上了一口较为干净没有恶臭味的空气3星基础1星鼓励
#
# 9500 一直想看的一个片
#
# 9600 100分钟的ppt
#
# 9700 是挺好看但是豆瓣评分高得也太不正常了好看的地方非常好看范爷挺帅的不知道为啥都黑她但言情戏部分实在无聊而且魔形女本来就是大配角结果因为大婊姐拿影后了就跃升为明明没戏硬加成主角的哈里贝瑞原来主角全程酱油真是世态炎凉啊
#
# 9800 全明星加高科技唤起封存于记忆中的漫画英雄绿巨人过分强大正常时智商超群变身后武功超群队长有点虚上个天还得让人抱着上去钢铁侠更像一个相声表演艺术家黑寡妇的紧身衣和厚厚的双唇很有杀伤力雷神和反派王子真是一对摆POSE装酷的好兄弟
#
# 9900 全在吃第一集老本从我只是一个宝宝的恐怖卖萌到少带一件装备的人物强扭金曲到了第二辑连彩蛋都变成了巨无霸套餐拉拉扯扯两个多小时貌似环保温情无害但坑爹坑大了
#
# 10000 爆米花电影的最高境界
#
# 10100 郑重加入诺兰五星脑残粉俱乐部
#
# 10200 真的不能再棒全程无尿点游戏闯关加源代码加逆转未来加环太平洋加盗梦空间即视感爽到爆高智商需思考我一定要再看一遍
#
# 10300 古一法师的戏份是全片精华除此以外是剧作最为单薄的漫威电影我称之为魔法版蚁人剧情remake美剧化的台词故事细节粗糙不合时宜的幽默就一白开水似的叙事加点炫的特效就没了这种一味堆砌视觉效果和高深概念而没有任何深入诠释的电影只会让人觉得莫名其妙沦为娱乐玩具
#
# 10400 在布拉格看的胶片首映很失望首先必须承认这片子的范畴和眼界都是无可比拟的可惜诺兰想探讨的东西太多以至于没有把任何一个话题深入探索整个家庭戏和爱啊什么完全不必要而星际穿越对人类的意义时间成为另外一个维度之类的有趣话题则浅尝辄止下一个2001何时回来呢
#
# 10500 这种在观看之时激动不止与观看之后难以平复的银幕震撼感无法形容宏大的格局里无尽的人情奇妙的宇宙复杂的时空融合着被表现到极致带来的内在力量感异常强大二刷体会到了异常震撼的音效剪辑
#
# 10600 今年的几部热门超级英雄片看完觉得我对这个题材要求其实好低像天启这样挂羊头卖羊肉就行了其他不点名了
#
# 10700 我们都有一个划掉家划掉妈名字叫玛莎
#
# 10800 一个半小时组队半小时死光最后领导莞尔一笑说革命曙光不远啦这特么不就是太空版的十月围城吗如此鸡血电影势必将深得我国屁民厚爱
#
# 10900 出生星情緒感覺哭家人SouthNode南交點靈前生一直做的事今生留有前生一直做的事可繼續做的事SimonPegg處女星12房其中1房ChrisPine水瓶星5房獅子ZacharyQuinto白羊星5房獅子ZoëSaldana白羊星9房射手JustinLin獅子星12房其中1房IdrisElba蟹星12房其中1房
#
# 11000 runoscar
#
# 11100 打斗激烈马拉松飞机跑道女神领便当
#
# 11200 一股子百事可乐和炸薯条的肯塔基乡村肌肉味和大多数RB一样再怎么努力也就那样了
#
# 11300 为毛高智商坏蛋每次都是听古典oヘo
#
# 11400 飞行密室搞得我快疯了快疯了快疯了快疯了快疯了连姆大叔好有说服力啊最后那个狗血有点傻
#
# 11500 爆破肉搏小幽默该有的都有了可惜锤哥死的早了点
#
# 11600 反正就是各种打就是余男在里面有点不伦不类的
#
# 11700 从前有一个渣攻勾搭了一个棒子公务员受去做任务完事后嫁祸给受自己就跑去转战色害公务员受变成了第一杀手受N年后他还偷了杀手受的飞机自称要拯救世界结果中了腹黑DOC霍普金斯的计为了杀DOC最后渣攻把杀手受的飞机炸了把本来要原谅他的杀手受气炸啦渣攻还当着杀手受的面跟女人亲热
#
# 11800 非常理想化和少年派一样都是一种局外人的角度来表达的故事感觉少年派是一本黑暗童话钢琴师是一首抒情诗
#
# 11900 我本是男儿郎到我本是女娇娥程蝶衣的执着一旦认定就一辈子不会改变他想跟段小楼唱一辈子的戏差一天差一个小时差一分差一秒都不是一辈子人生如戏小楼可出可入蝶衣却入戏不出而你又是谁是小楼还是蝶衣
#
# 12000 四次更迭艺术的变与不变拍到这个份上了大家也就自己品吧
#
# 12100 感谢字幕组的童鞋
#
# 12200 或许是很多姑娘大叔控的根源
#
# 12300 世界上最温情的KILLER
#
# 12400 你我不在
#
# 12500 我哭了
#
# 12600 开始断断续续看了片段感觉不是自己的胃口后来下定决心看一遍不得不说自己当初错了汤姆汉克斯不辜负自己名字里有个汉字
#
# 12700 起来不愿做神经病的人们
#
# 12800 似乎飞越疯人院是影射苏联等国其实该片是揭露了美国自己的家丑影片中所描绘的那所精神病院是美国病态压抑的社会缩影正如有的评论指出该片以触目惊心的画面揭露了资本主义文明社会的弊病压制人性和束缚自由现代的社会竟如此恐怖给欧美观众以极大的冲击昔日的好莱坞电影也很喜欢涉及精神病患者的题材但目的是渲染病态心理飞越疯人院尽管撷取类似题材却有一定的寓意语风犀利富于揶揄色彩但这部电影颂扬的那种为了个性解放而孤军奋战的英雄由于找不到正确的解放道路最后还是被无情的社会所吞噬
#
# 12900 太精彩了
#
# 13000 金凯瑞的演技超赞
#
# 13100 这究竟是怎样一种残忍
#
# 13200 好诶
#
# 13300 电影院傻瓜才会辛辛苦苦地去取西经我只想永远做个快乐的山贼
#
# 13400 好看一个小人物的成长故事很好笑但是又很苦涩张柏芝年轻时候太灵了
#
# 13500 很真诚周星驰最好的现代片每个人都是个演员努力奋斗最好的情话我养你啊柳喂看前面多黑啊什么都看不到尹也不是啦天亮之后就很漂亮
#
# 13600 搞笑搞笑
#
# 13700 无聊透顶
#
# 13800 还算值得一看但我不觉得是喜剧
#
# 13900 我是编剧的话结局就一辈子不让那个女孩知道
#
# 14000 智障男的冤狱可爱女儿偷进牢房各种温情与自然笑点使劲抒情想当然大光明结尾精彩温情片韩国这种片总有点刻意但真让人觉得温暖尤其雪中追忆热气球
#
# 14100 好难过
#
# 14200 一个童话
#
# 14300 素媛说我们回家吧的时候拉了可可梦的手我一下子想起小时候每次过家门口那条小马路的时候明明是大中午的没有车连个人影都没有的小窄胡同老爸却把我的手抓得紧紧的都捏红了过那条马路用了20秒但是是我一生中最幸福的20秒
#
# 14400 再多各自牛逼的时光也比不过一起傻逼的岁月
#
# 14500 早就看过了日剧死化妆师所以对这个并不是很感冒不过也架不住大家都说好看果然情节方面和连续剧没有任何区别不过配合着大提琴让悲伤的感觉传达的更好只能说ok的电影
#
# 14600 没猜中结尾
#
# 14700 灵与肉罪与罚
#
# 14800 畸形恋
#
# 14900 不用多说大家都知道
#
# 15000 剧本很有心思对白简单却意味深长汤姆大叔的演技很醇厚总之是一部让你笑让你哭的电影
#
# 15100 不一样的TomHanks同样的励志
#
# 15200 斷臂自救求生欲人的本能
#
# 15300 我还是质疑奥斯卡那伙人的口味这部电影到底哪里比飞行家好了
#
# 15400 台词经典一直2小时听到CAGE的声音真的是太惬意完全沉迷在男人完美滴声线里
#
# 15500 很励志的电影
#
# 15600 真人真事改编bobo其实是个幸运的人无论是家人还是社会不少人接受他并且鼓励他这让我坚信人间的温暖永不会消逝不过我最羡慕bobo的是他的乐观这需要一个强大的内心才能走到今天这一步贴个真人视频httpwwwtudoucomprogramsviewqdwrEn5JmKc
#
# 15700 之前在CCTV6看睡着了后来再找来看完发现真是值得看完以前佳片有约为什么不放在黄金档10点过后很好玩吗现在的沦为烂片有约了也没了期待
#
# 15800 是我智商变高了还是这个世界越来越弱智真没看出有多好多精彩反而有点觉得用力过猛励志的简单情节过于俗套唯一的亮点是在森林里的画面的确太美又嘲笑了一下中国的动画美术师们审美真的很重要
#
# 15900 影片的敘事結構表現手法乃至主題幾乎都拷貝自HowtoTrainYourDragon當然在此基礎上有所提升就影片本身而言值得肯定人物性格層次分明成長層層推進主題小則關於兩代隔閡大則講述人類對新事物的追求但是就創作態度來說是一種保守主義劇情也刻意服務3D效果了些
#
# 16000 从头到尾都很幸福的一个片子太温暖了导致我总怕有什么转折或者起伏幸好它没有男主萌萌哒rachel也萌萌哒男主的妈是DW火星之水的船长印象很深的好美丽整个片子看得好温暖好舒心可惜片名翻译得不好
#
# 16100 據說ColinFirth那段故事出自他真實經驗不過整體看下來沒有特別打動我的部分
#
# 16200 女孩子不喜欢你不是因为你是书呆子而是因为你是个混蛋
#
# 16300 这到底是要表现他妈的什么
#
# 16400 一般吧宁浩黄秋生等纵多明星很让人出戏
#
# 16500 搞笑又感动伟大的父爱残酷的现实泪点太多
#
# 16600 姜还是老的辣啊哈哈哈结尾和喜宴有异曲同工之妙其实一家人住在一个屋檐下照样可以各过各的日子可是从心里产生的那种顾忌才是一个家之所以为家的意义
#
# 16700 越来越喜欢李安的电影了
#
# 16800 明明不是悲剧就是不停的被感动着
#
# 16900 一个怪蜀黍教书把学生教死了
# 17000 国内难得的好影片质量不错导演功力深厚编剧也很棒演员演技在线五星鼓励不要太骄傲
#
# 17100 太好看了十星推荐就是太短了呀
#
# 17200 觉得不太好看为什么分这么高呢
#
# 17300 一只好马桶的标准再脏也能带你到异度时空遨游
#
# 17400 结尾很是感触
#
# 17500 音乐比电影还要好
#
# 17600 起笔略淡渐入佳境没有卡司年轻演员演技不错没有车祸堕胎虽戏剧冲突不强烈但也感人
#
# 17700 鬼鬼是个好演员可是完全的选角失误了范逸臣好乡土乔任梁的颜跟十年前的完全不一样娱乐圈真是个大染缸
#
# 17800 剧情太老套了也没有颜值能撑着看下去
#
# 17900 被之前发的主题曲带过来的说句题外话还挺好听的台式青春片的画面感还是在的就是台词听起来还是很别扭情节也没有让人感觉别出心裁
#
# 18000 精确地捕捉到了少女情窦初开的小心思加上对高中生群体生活细节方面的展现恶作剧交男女朋友和不同个性的同学叶老师这个角色的作用挺鸡肋除了充当个学生眼中的女神真的无法提供任何戏点美术老师的塑造也很扁平一些空镜头的作用不大孔雀还能理解但雕塑之类的真的没有必要67
#
# 18100 这片子跟睡在我上铺的兄弟没有任何关系不管是何种题材还是一拍就土的老毛病陈晓及其没有存在感也不适合这个角色而刘芮麟和李现则更耀眼把青春无脑的表现为插架破处和性幻想简直粗俗又肤浅
#
# 18200 在青春片泛滥的当下还算保持了一定水准但一帮鲜肉还是没能挑起大梁并无亮眼的剧情拖累了口碑
#
# 18300 或许是因为当了老师的缘故想做一名好老师想和学生成为朋友深有感触突然有了一个目标一个理想曾经不喜欢当老师觉得自己不适合当老师现在却想做好它
#
# 18400 久违的香港式幽默开头拍的还不错鸡汤被灌了几碗几位演员演技都在线个人比较喜欢再见拜拜这个故事卫诗雅演的不错三女智斗渣男的故事想必很多人会有感受这种脚踏几条船的男人太多了很有现实意义电影结合了很多舞台剧元素也算有着新意提点个人意见方力申和李明顺换个角色
#
# 18500 看到最后康乔的那句跟我走直接击溃心理防线了采钰小姐姐好美啊啊啊啊啊韬韬最近这几部戏也是进步了不少哭戏很真实
#
# 18600 看起来很精彩的样子诱惑人心无极限真是爽演员的造型别具一格
#
# 18700 这部玛丽苏至极的竟然上映了
#
# 18800 很早前看过原小说明明应该是绝对的狗血小言的没想到电影柔化了很多磨平了不少的小言诟病韩国导演在唯美叙事上还是可以的能把这种小说拍成这样还是有技术的女主新人倒是挺惊喜的表现的挺好吴亦凡演绎的也很好惹人怜爱韩庚这年纪扮学生那边真是有点违和了
#
# 18900 为了刷5分的脑残粉
#
# 19000 爱是永恒的话题无论是战火纷飞的年代亦或是时下的我们是啊诱惑总是那么多人心总是那么难揣测可是不试试又怎能体会到那只有你和爱人之间专属于彼此的酸甜苦辣呢借用影片中的一句话爱情是你准备好了它才会发生的吗所以不要犹豫了勇敢踏出那一步去爱吧
#
# 19100 为什么评分这么低啊剧情什么都还可以啊好几段都差点哭了而且就算撇开演技撇开剧情光听配乐光看刘亦菲都起码给四星啊再强调一下刘亦菲这电影里的职业装打扮真是太太太适合她太太太太美了看得我都呆了
#
# 19200 把一星都点了个赞
#
# 19300 这个电影我觉得挺好的导演敢于用新人而且几位主演表演的都不错那个女主真的看起来很清纯
#
# 19400 是一部纯美的浪漫爱情喜剧片但我更喜欢主题曲中那句别把放弃当洒脱是啊对于爱情是这样对于亲情友情又何况不是这样呢大多数的我们太容易放弃只为了寻求自己所谓的洒脱
#
# 19500 杨幂烂片保证
#
# 19600 玛丽苏的套路毫无新意编剧导演们就不能给我们讲一些不一样的爱情吗
#
# 19700 听听歌看看胸注彭于晏跑起来
#
# 19800 我是2001级和乔燃一样都得了新概念高考结束那年夏天北京申奥成功了影像里蓄谋饲养的召唤兽只会击中那些感同身受的人在那个时候只要夏天的午后刮完风就会觉得好像过了一辈子一样漫长喜欢一个人的时间如此短暂却好像可以穷尽一生我们如此无知所以才如此珍贵
#
# 19900 人生苦短来的时候不曾相伴走的时候爱人作陪其实也是很幸福的一件事啊何必瞒着呢
#
# 20000 1星半吧这个结尾实在让人吐槽无能
#
# 20100 这部电影成功刷新了我对大中华区新生代年轻演员的整体印象以前我觉得他们没有演技至少活泼可爱现在我终于知错了
#
# 20200 麻痹一米八四的大蛋糕呢滚球
#
# 20300 一般是不是青春类电影最后男女主都不在一起
#
# 20400 示范怎么用小时代的素材拍出正常的小妞电影小时代闺蜜纯属基佬腐男意淫而黄真真在讲连接闺蜜的情感纽带叫嫉妒小女生我看完感同身受情节偶尔发飘但还不算脱轨模糊地缘关系用剧情弥合杨子姗的气质突兀植入包括导演及女人那话儿在内的一众广告最后大发主演的电影我都四星起
#
# 20500 略不知所云访谈部分还不错服装也还比较养眼薛凯琪的声音有时候听起来怪怪的杨子珊的演技不错有前途
#
# 20600 剧情一般都是套路但彭于晏颜值真不错
#
# 20700 一股棒子泡菜味
#
# 20800 有了它小时代终于不垫底了说它比何以笙箫默好的站出来论颜论演技论故事的扯淡感情的莫名其妙这部明明比何以更差看了它就知道中国烂片只有更烂没有最烂何老师还是回去主持吧李易峰大银幕上的脸真是惨不忍睹祸害小学生审美就好了干嘛来大银幕上展示丑陋可惜张慧雯在基片里打酱油
#
# 20900 整个厅里的人看得都笑疯了何老师看来你这个导演成功了
#
# 21000 内地导演拍红色主旋律真的不如香港导演厉害
#
# 21100 卧槽解救吾先生真是你拍的你出来解释下
#
# 21200 对比分手大师恶棍天使更恶俗更用力过猛希望不要再有第三部了
#
# 21300 渤哥为啥要来掺一脚这是有他的片子里分数最低的吧
#
# 21400 超级大烂片情节生硬故事前后撕裂一众明星纷纷突破下限拍出生涯最烂的一部电影女主角感情转变也不合理满满的直男癌意味王宝强你是看了全世界没过瘾非要把柳岩塞给岳云鹏吗
#
# 21500 原来以为他们只是不懂喜剧后来发现他们根本就是不懂电影只是来糟蹋电影的在两千万观众的鼓励下他们还糟蹋得理直气壮的甚至糟蹋出崇高感来了
#
# 21600 呃我真的没抱期望但是仍然被烦死了一开始还冷笑两声后来都不愿嘲笑了毫无诚意我不是不会看烂片但是没诚意的烂片我是不看的套路都是套路
#
# 21700 如果说澳门风云还打着情怀这张牌本片就啥也不是了即使一个帅过的搭档一个帅的可惜帅的都是徒有其表前面那位口音问题无可避免后面那位演技问题老生常谈剧情就是各种拼凑配角更是配出了一致一致低能王晶的水准怕是年龄大了急剧滑坡了
#
# 21800 看完后真的是万万没想到
#
# 21900 万万没想到会这么难看
#
# 22000 佟大为不错赵薇及格黄教主没救了算是能看的爆米花片但硬伤也不少
#
# 22100 在美人鱼终极预告出来之前我是打死都不会想到最后竟然做出的选择是看澳门风云3但结果还是自己作死了尴尬到极点系列最烂卖情怀炒冷饭都弄得那么七拼八凑无底线还有铠甲勇士乱入小学生智商感觉王晶可能已经疯了吧
#
# 22200 再一次印证了港片的没落和这班巨星圈钱的底线
#
# 22300 这部电影是去同学家玩的时候她请我看的看完之后我后悔了为啥要去看电影哪怕逛街也好啊影片里闺蜜决裂的莫名其妙的看的我一头雾水两女主确实美然而除此之外也没啥了很无聊而且说真的我看完之后在很长的一段时间内都不记得我看过这部没有好的让我惊艳也没有烂的让我想起就郁闷
#
# 22400 即使是有经济基础在一起五年两个人之间依然会出现裂痕有幸结局是好的或许只要是对的人只要坚持只要还相爱终究会走到一起吧结局看哭了很不错的一部电影为每一位演员的演技点赞
#
# 22500 为什么打四星呢因为有凤小岳其他的想给负分太烂了
#
# 22600 说实话除了约会男女谁会去电影院看这个
#
# 22700 贺岁片么
#
# 22800 确实挺烂的但电影院仍然有观众笑出声来中国观众是多容易被满足啊
#
# 22900 说相声不伦不类演电影更次
#
# 23000 剪辑混乱
#
# 23100 笑不出来反而尴尬死了毁我憨豆不能忍
#
# 23200 无聊
#
# 23300 伊能静映后见面会诚恳的打动了我
#
# 23400 噩梦吧原著和原电视剧都是水准之作我不知道为什么陈意涵有勇气来瞎山寨这个傻白甜适可而止
#
# 23500 没看过老步步惊心新的看着不讨厌也没多少惊喜3星吧
#
# 23600 明知道痞子是出来圈钱的嘛可是依旧
#
# 23700 感动
#
# 23800 宫崎骏的作品大气磅礴让人动容
#
# 23900 第一个故事着实让我惊艳了一下
#
# 24000 很精彩画的很细腻男主角很帅是我的dreamlover类型
#
# 24100 神之一役
#
# 24200 虽然这么说有点对不起00但是我对黑桐完全无感比起善良我还是更偏爱聪明冷血的家伙以及果然奈须不是我的菜啊
#
# 24300 萌杀得鼻血纷飞啊
#
# 24400 天也放弃了我们
#
# 24500 没玩过游戏的看着意犹未尽啊
#
# 24600 喜欢飞行员因为这个原因看的
#
# 24700 华丽
#
# 24800 燃到爆表吐槽到爆表啊喂混蛋
#
# 24900 会心一笑的少女心时间
#
# 25000 贞本义行的人设太对我的口味了MADHOUSE水准一流细田守
#
# 25100 猫咪萌点大红蝴蝶结萌点
#
# 25200 我怎么又觉得不了了之了
#
# 25300 久仰没想到那么唯美乌托邦的故事也有一个地球本位主义的核心
#
# 25400 简单粗犷的美好
#
# 25500 画面不是我喜欢的那种故事情节不错
#
# 25600 洗澡的时候踩到肥皂摔死的生命真是脆弱
#
# 25700 现实主义闪耀光芒今敏一生中必不可少的一部作品
#
# 25800 吃光所有鱼的大白猫大盗
#
# 25900 漫漫的都是意淫
#
# 26000 思想够深刻
#
# 26100 这个系列早就超出了一般动漫的范畴了
#
# 26200 看的第一部的大友克洋的动画居然是92年的作品了画风和押井守的很不一样故事情节今天看来有点老套
#
# 26300 杰作电影般的质感不过不知道换成真人拍摄会不会流于无趣呢
#
# 26400 其实我已忘记他的模样世界这么乱只有幻影好看
#
# 26500 嘛有点老套
#
# 26600 这个太华丽了感觉全员废话太多豆瓣的剧情简介真是剧透了个底儿掉啊还好我之前并没有看
#
# 26700 我不是很喜欢
#
# 26800 各种奇思妙想情色暴力
#
# 26900 好燃啊好燃啊
#
# 27000 海豆同人
#
# 27100 看不大懂
#
# 27200 这部片主要是show画面来的多次的角度大转换让画面异常华丽啊
#
# 27300 重走一遍剧情果然这货后篇才叫有爱
#
# 27400 没有前面出彩但是女神和BGM嘤嘤嘤可惜不会再有盼头了
#
# 27500 ９１０螳臂当车的少女剧场版这一集基本上是群像故事挂逼少女的戏份并不突出
#
# 27600 虽然对令人张目结舌的机动性和故障率和装甲与口径等等有疑问不过毕竟不懂这部片子的好处是内行看门道外行也能看热闹而且挺热闹的虽然以战车为主体但是打斗还是很精彩的就这点而言故事主线清晰明朗娱乐效果良好声优充分
#
# 27700 太好看了
#
# 27800 意识流
#
# 27900 仅仅是将时间穿插其中
#
# 28000 男儿当自强响起的时候还是很燃动作设计场面铺开美工道具都很出色配角也很有存在感年轻一拨还是弱了最弱的就是台词你让黄飞鸿讨论梦想这事真心受不了
#
# 28100 打打打杀杀杀炸炸炸纳智捷
#
# 28200 重复杀破狼和导火线的路数没意思
#
# 28300 不知所云
#
# 28400 景甜果然没让我失望依然捍卫烂片女王的宝座无可动摇电视剧式走过场的表演模式睡了一觉依然能理清脉络洒狗血的剧情让编辑费尽挠细胞2013警察大哥唱着跑调的拯救来到我眼前亮瞎了我的狗眼
#
# 28500 长的太像我爸了大鼻子三角眼生起气来沙皮狗的脸
#
# 28600 有点不伦不类啊
#
# 28700 一切都很老包括感情戏都是上世纪80年代那种你来啊你追我啊追上了我就是你的了的套路不过冲那踢飞烟头的一脚就值三星
#
# 28800 余文乐乐
#
# 28900 无亮点一颗水花都不起的电影
#
# 29000 这片子我能哭两次
#
# 29100 极品飞车
#
# 29200 本来5分的片子保罗沃克一死立刻7分要不景甜也去死一死
#
# 29300 烂出汁液了
#
# 29400 为了那一脸无比惊艳的雀斑一星吧还是
#
# 29500 杰森斯坦森和车一起进化
#
# 29600 比起第一集想象力严重缺乏好莱坞真是奇怪老让一些不入流的导演来操作大项目
#
# 29700 白幽灵的逆袭
#
# 29800 线放的很多都没好好收
#
# 29900 杰森要继凯奇之后成为第二个烂片帝
#
# 30000 流水作业一如既往的心狠手辣
#
# 30100 本片意欲复古增加搞笑桥段但丹尼尔克雷格根本不适合搞笑魔头过分中二真想把他拉出来丢进日本少年向动画中邦德手枪射下直升机明显抄袭金将军最后是全片色调偏土灰缺乏明亮色彩
#
# 30200 不是郭达就没那个味哈哈哈哈哈
#
# 30300 打得欢乐呵呵后
#
# 30400 25
#
# 30500 注水俗套自我透支何必呢
#
# 30600 还行
#
# 30700 Batman是最不漫画的漫画英雄也正因为这一点使之最有可能成为跨越犯罪剧情片和漫画英雄片界限的特例而这一次编导精准的抓到了这一点把这部电影打造得丰富严谨又酷劲十足无论是满足视听还是人性复杂层面的挖掘上都做到了堪称完美
#
# 30800 其实感情分有一部分当然片子也不差
#
# 30900 中等偏上
#
# 31000 中國版的蜘蛛俠
#
# 31100 老港片的感觉还在但就是故事有点怪甚至有些情节不知所云估计是因为删减的原因
#
# 31200 鲍德熹的故事告诉我们唉反正就是该干啥干啥还是去摄像吧
#
# 31300 这种电影别再拍了太恶心了
#
# 31400 片子里碎了好多玻璃
#
# 31500 其实我对这种有美男有动作有笑点的香港片没有抵抗力
#
# 31600 中国版阿甘不是傻就能火的幸好尤勇和黄秋生支撑了一下门面
#
# 31700 两位帅哥当警察可不是闹着玩儿的
#
# 31800 惊现珊瑚海mv鱼缸片段
#
# 31900 还不错的片子
#
# 32000 我靠遊俠跟和尚打得也太難捨難分了吧00在一起吧琵琶姐為毛老用第三人稱哩搏出位咩那你輸了喲天下的男人都是騙子一出頓時真理之光普照大地吖所以乃是受過情傷才變白頭的麽還是本來就是拉咧XD另外白髮娘的眼角開得真不是一般的大哇小心容易受感染喔
#
# 32100 商业片一部一看就忘
#
# 32200 案子很普通特技还不错值得鼓励
#
# 32300 三星改两星成龙真乃神人也你怎么就没掉火山里呢不是更感动
#
# 32400 1从最后结果看是灾难片可惜没任何死伤报道2多次把尹子维看成吕子乔3孩童和姚晨俩位问题都很明显4现在警察怎么说话我不知道这样正腔的很少见5黑暗心理算亮点吧6胡军莫名其妙地昏迷到结尾也没照下7林妈与姚晨没火花是明智的
#
# 32500 点映的时候提前看了第二部好多笑点和感动点但是故事转场有点生硬突兀不顾虑那么多的话这两部电影都还值得一看啊
#
# 32600 看到这一部已经有点疲劳了
#
# 32700 对财大气粗弱智浮躁当代中国电影来说心迷宫是一记响亮的耳光一柱挺直的腰杆闪回的时间跨度循序渐进一环一环都无缝接合荒诞戏谑与绝不显得业余的非明星表演放置在宗族家法大如法的地域一切剧情都得到合理解释不仅是编剧意义上的突破之作更在应对目下审查机制的方略上摆下良好镜鉴
#
# 32800 其实加不加那字幕你我都知道那父子不会去自首
#
# 32900 剧情可以主要题材吸引人
#
# 33000 超赞现在完全佩服韩国了感觉我们天朝要拍这种电影估计得100年后在这种狭窄空间里的叙事极其考量编剧和演员的功力看到最后一幕只能说服了
#
# 33100 宁浩目前为止最差的一部完全不值8分看评论也可能是广电总局那帮傻逼的错
#
# 33200 可怕的女主巨赞的RosamundPike随性一点不然真容易崩溃对完美起疑对不完美深信不疑
#
# 33300 叉着腰牛着屄嗨起来
#
# 33400 保留了韦斯安德森独特的运镜构图色彩剪辑音乐特色的同时故事的讲述和人物的塑造也同样成功尤其productiondesigner的各种空间营造监狱雪山缆车等已不再是使影片风格化的辅助而是直接参与叙事大部分时间主角就像身处一个迷宫连环闯关游戏一样一气呵成爽就一个字
#
# 33500 充满了80年代的流行元素被橙色点缀的科幻世界还有那些伟大的80年代的摇滚金曲坐等票房冠军
#
# 33600 坐我身后那个剧透的小子一定会遭报应的
#
# 33700 有些特写镜头难免故弄玄虚之感特写里莫文蔚的嘴显得好凸最后一幕还挺好看的徐峥总是脱不了以前那个猪八戒的影子剧情悬念还能看下去
#
# 33800 因为幕后人员是埃舍尔的脑残粉地板挂画装饰海报梦里的城堡排序都是埃舍尔而且莫文蔚是我的女神之一最后EVITA的YOUMUSTLOVEME更是我的挚爱歌曲所以不理智的五星全因这么多我喜欢的元素都在一起了3
#
# 33900 不考虑原作剧本自身这个翻拍是凌驾于体制之外的社会群像面面观我以为撇清由演员塑造人物形象电影的可看处仍存在对白与演员走位体现1从众心理的可控性2排他性和竞争性的思辨3绝对集权下的精致利己主义者4大众仇富心理影响自身立场判定5思维取决临阵倒戈6结尾强加以求过审
#
# 34000 虎头蛇尾两星半
#
# 34100 很电视剧的镜头语言很牵强的逻辑浪费了张家辉和吴镇宇
#
# 34200 演员们的褶子加起来可以绕地球两圈
#
# 34300 真不敢相信我又去看了2
#
# 34400 公举你别抢戏了行吗人家的魔术明明就是瞎编你还跟着乱演
#
# 34500 火锅我懂但是真没看出哪儿是英雄来请问这电影是致青春吗怎么现在什么片子都走煽情忆青春的路线看的人好烦躁打架的戏拍的很好但你为毛要让顾大人演这种苦大仇深的戏
#
# 34600 我觉得应该还藏着一个导演剪辑版吧完全可以更进一步鼓励多加半颗星其实是给老乡白妹子的
#
# 34700 还差一点点就是杀人回忆
#
# 34800 陈思诚较上一部进步明显王宝强太适合喜剧看着他的脸再加上他的口音不用演我都会笑出来小鲜肉刘昊然完成的很好可帅可逗比不错
#
# 34900 对于这样的现实题材电影真的是不好评价明明是略显文艺的剧情片却拍的和爆米花电影一样就像机器加工出来的煽情部分和动作场面被安排得严丝合缝刚煽完情就打架打架打累了再煽情但是电影想要表达的东西是值得关注的钻石行业的内幕以及非洲社会的军事安全让人触目惊心
#
# 35000 就小李子和康纳利也要五星啊
#
# 35100 人太多
#
# 35200 没有强烈赶脚
#
# 35300 老片惊喜不多表演加分
#
# 35400 气氛把握得准确演技无可挑剔
#
# 35500 以为会烧脑子没想到只烧了腚
#
# 35600 哈从一开始就预感到了结尾凯文大叔一依既往的淡定
#
# 35700 没配音就好了
#
# 35800 天才和神往往也是一线之隔
#
# 35900 主角走進美國的駐軍地時當地土孩正以主觀鏡頭穿牆窺視但當美國嚮導描述周遭環境的話一出畫面立刻跳接空拍遠景來回交替一邊是人眼一邊卻是天眼這並不奇怪當美國人隨口唬稱天上有無人機在瞄準就能令當地匪徒嚇到開路他們有何資格不用或不該用上帝的目光看待人間
#
# 36000 你确定这是Stark工业而不是Wayne集团基调太沉郁了超级英雄们神的外壳被尽数剥掉露出来的是他们作为人所持有的情感软肋这种设定对照前作的欢乐吐槽世界观显得很违和虽然手撕机器鬼子延续了天然萌可漫威情怀硬生生变成少女心真是谁都救不了
#
# 36100 喜欢
#
# 36200 鬼才小哥说爱隆会议是以纪念指环王里的第一次秘密会议命名的一看肖恩宾就在旁边黑脸坐着小哥一定知道肖恩宾演的人族王子波罗米尔在爱隆会议后就惨死了这个梗简直快把人逗死了
#
# 36300 这算是近年来美剧导演最狠的一次逆袭么美队笑喷我了
#
# 36400 好莱坞的合格流水线作品但时空转换那一段太酷炫所以加一星
#
# 36500 不觉得好看
#
# 36600 真人版里约大冒险有赛车有枪战有壮汉肉搏又有美女和沙滩风情有罗汉系列一般各具特色的帮手有间歇抽科打诨的笑料整个片子泛着男人式的野性和硬气结尾抢劫的简单加粗暴更是与故宫劫案遥相呼应这回在剧情上颇下了功夫合格的商业电影值得去影院看不看这个省钱看建党伟业么亲
#
# 36700 这个系列里面最好的一集吧看得很爽
#
# 36800 电影自我感觉最棒的欧美动作电影了爱德哈里斯出场超男人
#
# 36900 吳宇森嘛要有白鴿要有教堂要有火藥要有浪漫要有happyending
#
# 37000 表演技术一流故事一流导演与故事编排不入流
#
# 37100 徐老师在票房不足50万的倭寇时期就预言要连拍七部为武学正名现在小说集子影像化的工作真的一部部排上日程了令人欣慰或者说这简直是个奇迹我本以为师父影像归因于曾与王家卫搭伙且砸钱了但看完紧挨着倭寇拍的柳白猿我才意识到这种改变是徐自己琢磨的牛逼
#
# 37200 那个时候的审美就是风情之美现在的审美感觉在下降
#
# 37300 还是那年代的演员好啊
#
# 37400 武痴
#
# 37500 细节精准简洁流畅打斗克制而凶狠有谍影重重的影子值得一看
#
# 37600 韩国片越来越好结尾有点谍影重重何正宇总演苦逼坏蛋居然是高智商的X而且导演是他哥有出2的节奏全智贤瘦了好多
#
# 37700 冗长混乱几乎没有主线看得人云里雾里剧情几乎是断裂式的甚至你都不知道自己在看什么男的性格各异女的率真大胆因其混乱许多人物塑造单薄人物走向几乎没有交待总之是一部看后基本没留下什么印象的影片全智贤的塑造过于风骚轻浮不喜欢
#
# 37800 除了不伦不类的国语听着别扭其他还不错情节够娱乐结尾还反转又反转
#
# 37900 一般
#
# 38000 还凑合女主角挺可爱的
#
# 38100 精典王家卫
#
# 38200 被神化了
#
# 38300 我会告诉你们我是第一次看么我会告诉你们我看睡着了么
#
# 38400 绝对合格的爆米花电影但是此类电影的观影要诀之一就是一定要连续看不然就像煮熟又放凉的老玉米怎么吃都不是那个味儿了
# 38500 基情无限
#
# 38600 电影院看这些才high
#
# 38700 强大的剧本和手持出租车还是战斗民族的靠谱马特达蒙靠这个系列可以帅一辈子
#
# 38800 拖着个女人影响剧情快节奏发展因此跑上来就把她解决了JuliaStiles戏份终于比第一部多一点了
#
# 38900 傻乎乎的个人英雄主义影片也是挺好看的
#
# 39000 这片10年后再看就是个手撕鬼子的无脑剧凯奇叔胸大无脑的一直在犯蠢主角光环强大如超人连bunny兔子都徒手飞过五条街了库萨克白嫩帅一脸可惜角色设定也是从充满智慧的办公室探员变成了手撕鬼子的007你练练肌肉再演才有说服力好吗这片真是主流马尿啊也就布西米有看点
#
# 39100 关键是他要肥去看女儿啊这个设定太虐了啊驴蜀黍
#
# 39200 不死的主角可不可以死一次啊
#
# 39300 当个特工丈夫真是难呀
#
# 39400 结尾过扯
#
# 39500 导演的每个镜头都让人想再看一遍而不动声色的英式幽默也足以让人捧腹
#
# 39600 挺好的电影赞
#
# 39700 心中的超五星太喜欢了
#
# 39800 中规中矩
#
# 39900 大爱
#
# 40000 我心中的第一部电影
#
# 40100 笑面人的部分闷了点
#
# 40200 甄子丹模仿WWE里619的大段动作还真是有意思
#
# 40300 丹哥这几年是越看越帅哇
#
# 40400 动作设计相当出彩
#
# 40500 武打片就别提剧情了打得也有点混乱演员风格还是不够凸显
#
# 40600 啊啊又是谢苗这孩子原来是84年生的
#
# 40700 视效出色民族荣耀牌很成功
#
# 40800 为钟丽缇而看
#
# 40900 煤气那段很精彩
#
# 41000 还不错啊
#
# 41100 噼里啪啦呱喳咔嚓
#
# 41200 这绝对有丑化华人的嫌疑吧
#
# 41300 相当暴力血腥
#
# 41400 大暴走
#
# 41500 主题比第一部更宏大更深刻了直接着眼于政府自卫队精英部队毒贩一条线的黑暗体制政府与自卫队相互勾结互惠互利精英部队成了一枚棋子而毒贩反而成为了牺牲品超越了前作的续集精彩震撼深刻
#
# 41600 开始谈政治办一场听证会就能逮捕其中一二腐败分子巴西还没有完全烂透想起以前的黑手党电影法官被杀证人被浇在混凝土里警长在法庭上被刺那种绝望到地狱的感觉
#
# 41700 发福版尼欧重遇乞丐帮墨菲斯岁月啊
#
# 41800 马克吐温团灭普希金
#
# 41900 是惊悚片吧
#
# 42000 在天一小霸王面前这种讲法律讲道德讲良知的电影都白拍
#
# 42100 好不容易看完是个翻转再翻转再翻转再翻转翻转无数次的片子虽然翻转手法向来有其魅力但这部片拍出来却显得唠叨N次的倒镜N次在倒镜后切换不同人的角度主题是父爱但内容其实不算丰富林泰可以当椰酥了都
#
# 42200 男人也可以如此惊艳
#
# 42300 很惊艳相当水准唯一缺点可能是节奏真的有点拖沓
#
# 42400 去掉和谐结尾也加不了多少分
#
# 42500 VancouverFilmFestival参展影片多线程的故事线索充满了黑色幽默刘青云的表演非常棒在影院里看周围都是香港人气氛很欢乐一度眼泪都笑出来那些观影的老外却一头雾水不知笑点是啥
#
# 42600 结局不错这个小警察真的不够聪明导致最后死光了
#
# 42700 因为消失的子弹刘青云的开头今天终于恶补了这部杜琪峰的经典新警察故事美丽心灵禁闭岛式的结尾神作
#
# 42800 說教味也太濃了
#
# 42900 突然
#
# 43000 20081115菜园富贵离开北京南下深圳发展大家聚
#
# 43100 对古仔的配音很不满意
#
# 43200 林青霞真的很美电影很好看
#
# 43300 烂尾巴啊3D效果属国内一流
#
# 43400 我难得一见的好电影啊动作编排很棒剧情也不老套人物丰满为什么就这么点分
#
# 43500 那个时候是这类电影探索创造的阶段吧前后涌出了很多类似的中国古代侠客风格的唯美视觉电影
#
# 43600 当时的李连杰青涩未脱当时的李嘉欣惊为天人
#
# 43700 最后一段救母的戏虽然故作但还算感人
#
# 43800 导演你又来中国拍盲跟盲镜头故事任务设计都一样你有劲吗
#
# 43900 现在写影评门槛都这么低了这是某家粉写的艺人通稿吧卖的一手好安利
#
# 44000 我是来看看这部电影能不能突破国产恐怖片新低顺便看看大家是怎么骂这部电影的结果你跟我说评价人数不足那就尴尬了
#
# 44100 整部片子就是个用CG堆出来的灾难台词无聊幼稚到令人发指连最擅长的场面活都玩砸了镜头转场硬到不行电影在拍摄期间迈克尔贝就直播拍摄现场和网友互动一心多用这一部连配乐都不行了系列标志性的旋律都没出现也许派拉蒙都不想让观众再次听到这个经典旋律的时候会回忆起被变五支配的恐惧
#
# 44200 看得好尴尬
#
# 44300 看了许多电影之后许多电影就不必看了
#
# 44400 冲天火惊天破看到开头的欢瑞世纪就有不祥的预感果然人物毫无逻辑剪辑支离破碎故事一塌糊涂后半程全厅充斥着尴尬的笑声心疼林岭东连他最擅长的枪战追车戏也拍得特别无聊只剩吴彦祖和张孝全的脸可以看郭采洁的声音尖锐得一秒钟出戏都快癌症死掉了还东跑西跑添乱WtF
#
# 44500 烂到像爵迹那样的片起码还有一个简单明了的剧情可言这部片子连情节都是支离破碎全程智商不在线
#
# 44600 俄罗斯不愧是战斗民族战斗力爆表了
#
# 44700 我觉得一无是处四个字已经是很高的评价了因为这代表我坚持到底没有离场
#
# 44800 刘杰首先想不开的是去翻拍一部本就平庸的棒子片第二想不开的是找演技为零只会炒作的老偶像霍建华当花瓶男主反衬的秦海璐跟独角戏一样逼格尽失晚节不保
#
# 44900 不同于韩版的全家都蠢国产翻拍版主要是小孩子拖后腿另外跟讨厌韩版女凶手一样对秦海璐演的深井冰同样深恶痛绝反派都饰演得很成功
#
# 45000 好看尤其前半段各组人物出场一起在客栈一个画面中剑拔弩张太精彩了胡金铨还十分有倾向地把打斗戏分给了上官灵凤姑娘真是身手了得英气十足啊
#
# 45100 软糯
#
# 45200 胡金铨的特点就是高开低走和中间换了导演似的
#
# 45300 整体不错构思剧情以及反间等情节都刻意武打在那个年代如此也还好最让人吐槽的是最后的群戏pk明明可以一起上歼灭敌人非要等着同伴一个个被干死才出击也有点太低龄了对了胡金铨骨子里绝对是个女权主义者
#
# 45400 要嘛有嘛各取所需不同的人看出不同的优点我爱EC
#
# 45500 对于这部电影来说剧情并不是最主要的
#
# 45600 其实剧情神马的大概就值三星梅根福克斯身材太好加一星
#
# 45700 看了第三部回头重看第一部觉得第一部好纯真贝尔好美颜结构很精致
#
# 45800 比十二猴子差之远矣两相对比判若云泥高下立见
#
# 45900 四星半导演不加掩饰的对特摄片怪兽片机甲片致敬使其达到史诗片的厚重对有此情结的观众而言就像在庆祝童年情节虽简单浮夸但难以置信的美工CGI和IMAX视效机甲VS怪兽的热血爆棚酣畅淋漓声画组合气势恢宏两个GEEK不就是谢耳朵雷纳德吗
#
# 46000 kiangkiang大怪兽kiangkiang打怪兽
#
# 46100 一共两个演员其中一个20分钟就剩下我年少的女神桑德拉布洛克狂飙演技联盟号那段独白克鲁尼说你要懂得放手眼泪止不住下流
#
# 46200 节奏很有问题想象力和萌物来凑利用哈利波特的剩余价值特效也实在太挥霍捉虫寄生宿主消除记忆一切像是黑衣人的魔法版最后的灾害重建更是典型的敷衍了事
#
# 46300 精灵宝可梦大电影之神奇宝贝在哪里
#
# 46400 为了音乐给四星
#
# 46500 最好的超人
#
# 46600 老外打架就是猛啊莫名其妙主人公反正就打赢了中间有一部分睡着了不知道发生了什么结尾的时候以为都胜利了结果反派1号站起来就狂操了一阵子这个超人别看那么儒雅可真心的生猛不错
#
# 46700 我TM看的三个半小时的版本累并痛快着
#
# 46800 出生星情緒感覺哭家人SouthNode南交點靈前生一直做的事MarkHamill處女星8房蠍今生分析清楚記處女星8房蠍消滅獅子星8房蠍AdamDriver射手星10房山羊今生相信射手星10房山羊DaisyRidley蟹星12房其中1房今生情緒感覺哭家人蟹星12房其中1房HarrisonFord魚星5房獅子
#
# 46900 一部概念新颖软硬适中涉及语言学本体论及时间本质最终落脚到爱情亲情及人生态度过程重于结果的科幻杰作维伦纽瓦缓慢而坚实的节奏掌控与氛围营造让影片引人入胜后劲十足摄影配乐与艾米亚当斯的表演都是奥斯卡级别的最让人拍案叫绝的还是剪辑与叙事外星文字的视觉化9510
#
# 47000 20132212314
#
# 47100 超炫的车技
#
# 47200 从4觉得好看了
#
# 47300 比敢死队能好一点点
#
# 47400 充满喜剧色彩的动作片也是一部让你不想错过任何镜头的电影不知不觉便渡过2个小时这样的故事这样的电影我想也只有在美国这个自由的国度才能出现吧追求完全的自由对政府赤裸裸的感言期待看到续集
#
# 47500 动作和特技全部诚意十足紧凑的剧情很有爱的大叔包括偶然穿插的喜剧情节过瘾的帅片子
#
# 47600 再见昨天
#
# 47700 可能是看之前听说看到的剧情图片太多了有点小失望感觉影片刻意铺垫了很久就为了最后爆发一下龙哥的台词貌似不超过10句不过觉得阿龙作为导演和演员还是挺可爱的
#
# 47800 为了范我可以无视剧情特么的整部片子就是耍帅用的
#
# 47900 怎么就把XXX翻译成这烂名字烂大街的剧情就不说了极限运动才是片子的根本
#
# 48000 我以为有约翰尼德普跟海伦娜邦汉卡特的电影不会烂到哪里去可惜我错了这电影导演不是蒂姆伯顿最后那段枪战场面让我简直是求死不能除了不是黑白片到处散发着正午的味道是向正午致敬的影片吗
#
# 48100 毫不怀疑这次是收了奥迪钱了开头的奥迪末尾的大牛更加坚信了大牛早被奥迪收购了
#
# 48200 有些電影不靠譜但很好看這部電影不靠譜得很難看其實就是一部奧迪車的廣告片
#
# 48300 Tomorrowisanotherday
#
# 48400 黎耀辉不如我们从头来过
#
# 48500 人生路快乐少年郎
#
# 48600 又是忘记M很喜欢这部诶王祖贤长得就是女鬼型嗷
#
# 48700 朴实而无华平淡而率真毫无意思夸张和拔高的痕迹却因此催人泪下和小公主一样是我心中最好看的儿童电影
#
# 48800 我也幻想能坐在你的后座上紧紧抱着然后看遍城市里的每一个角落
#
# 48900 caonimagewangbagaozi
#
# 49000 哼鄙视你狠狠地鄙视你
#
# 49100 这个特工的转变是什么时候呢是对制度的无奈吗
#
# 49200 见过的最忧郁的眉眼
#
# 49300 美国和战争呵呵
#
# 49400 当我看到第三遍时我从五星里减了一颗星
#
# 49500 三年前想看的在高考还有三十天的时候看了剧本是神级的尤其是对话之下的那些行为细节和极限空间下的张力相比之下拿着教科书的这辈就真是够了啧啧啧豆瓣评分偏低94
#
# 49600 国师请余华吃饭桑拿一条龙了没有没有的话好意思
#
# 49700 莫文蔚扮丑还真挺丑
#
# 49800 那个背影的镜头还真是挺精彩的
#
# 49900 开心就好
#
# 50000 老公我煮碗面给你吃好不好
#
# 50100 还可以
#
# 50200 到处都是已经化为烟尘
#
# 50300 时隔十二年才看这部电影才发现好多经典台词都是从这里面出来的非常喜欢那个小镇就是包租婆讨厌了点中隐隐于世能力越大责任越大
#
# 50400 对不起除了大众笑点其他我都看不懂
#
# 50500 又被央6普及了一遍
#
# 50600 这个无语啊
#
# 50700 星爷经典搞笑系列
#
# 50800 好笑
#
# 50900
#
# 51000 妈妈看乐了
#
# 51100 俗
#
# 51200 很值得看的一部电影
#
# 51300 感動
#
# 51400 影片处理的很聪明并没有去质疑神和信仰而去声讨那些借助神的名义取私利的人然后最终引出一些善的论调
#
# 51500 印度电影总是能直戳社会最常见的矛盾无神论者有事比有宗教信仰的人更虔诚因为他们始终相信真理
#
# 51600 什麼玩意兒啊
#
# 51700 这片子能需要多少投资靠得就是够硬的煽情剧本和演技
#
# 51800 难看哭了但是表情夸张忍不住哈哈哈
#
# 51900 又看了一遍电影院当时要笑飞了想把五分都给树懒但是冰棍那里也很萌还有狐狸和兔子的互动反正要满分
#
# 52000 全程想揪兔子尾巴
#
# 52100 比第一部相比故事创新性与趣味性都大打折扣主人公已经变得不像坏蛋脉脉温情的主线让位于俗世爱情唯一不变的就是卖萌不止的小黄人
#
# 52200 电影快结尾处突然变得感人起来前面大部分都是在为后面的转折做铺垫
#
# 52300 即使故事有些拖沓有些太煽了但依旧不能阻挡我最后20分钟沉浸在泪水中最后我一直在思考生命究竟应该是什么样子无论你有怎样的理由终究一切都是要偿还的吧
#
# 52400 演员很好导演很糟
#
# 52500 和素媛一样都是散发恶臭的片都有不忍直视的逗比们给5星不管你们怎么想反正我是被恶心到了59
#
# 52600 看过几遍了宫崎骏的动画电影真的拍的不错
#
# 52700 从千知道的宫崎骏久石让
#
# 52800 太山寨
#
# 52900 此片在韩国以破千万级的观影人数再次创造本土纪录本片和熔炉恐怖直播很像很难用电影的评判标准去衡量题材远胜电影本身法庭戏基本用撒狗血配上宋康昊的歇斯底里看的还算过瘾可什么是国家法律对于弱者到底意味着什么
#
# 53000 人来人往勿失勿忘所有的两面性绝望与希望
#
# 53100 是一部催泪又震撼的电影光这种题材就该给高分每个演员演技都破表特别是赵薇的演技是个亮点
#
# 53200 想起来以前有个男朋友说想去日本乡下做农民我们还兴致勃勃地计划过很久现在想想也是天方夜谭大概乡村夏夜的各种虫子就能把我弄疯而且他那么忙总那么忙就连Line也是断断续续的我猜他可能没有那么喜欢我吧即便去日本长住是真的那个计划中的未来也没包括我
#
# 53300 看了半天才知道是同志题材晕倒
#
# 53400
#
# 53500 一次又一次悲剧的终结人生没有你的世界我还有什么好珍惜
#
# 53600 各种美好的清新小可爱
#
# 53700 结尾的好突然
#
# 53800 有梦想谁都了不起
#
# 53900 六颗星
#
# 54000 怎么觉得哈特好像服部平次原来是新一和基德大人的配音呵
#
# 54100 感觉自己家养了多年的鲜嫩多汁大白菜还是被别的猪给拱了
#
# 54200 爱的那么深
#
# 54300 中国香港
#
# 54400 原谅我不好这口
#
# 54500 青梅竹马的感情可望不可及结尾仓促了却成全了唯美
#
# 54600 一般
#
# 54700 我看过的最绝望的爱情电影深入骨髓的让我不再相信爱情
#
# 54800 和原著相比改动很大啊甚至都很难说是同一个故事了不过还是看的出来有菲茨杰拉德的那种享乐主义调调应该说这是一部各方面技巧都比较纯熟的作品特别是化妆太赞了不过看影片的时候总不自觉的想起时间旅行者的妻子都是包着幻想外壳但实质是纯粹的爱情故事
#
# 54900 故事蛮特别主要是看我的皮特
#
# 55000 看电影的间隙我一共考了四个学期的试从大一变成大三于是在第三次打着哈欠关掉它时就再没点开过
#
# 55100 一想到你呀就让我快乐
#
# 55200 最美的一见钟情
#
# 55300 世上有那么多的城镇城镇有那么多的酒馆她却走进了我的
#
# 55400 女主傻笑男主黑线剩下老妈和一群姐妹大花痴
#
# 55500 放到今天來看確實很一般
#
# 55600 蒂姆伯顿其实最好的作品是他的短片拍长片蒂姆伯顿讲故事的能力似乎有所下降不过他能把作品的情绪通过演员和场景淋漓尽致地表达出来所以这部电影你看的不是电影是寂寞
#
# 55700 winona和depp的故事
#
# 55800 我英语学习时的好伙伴啊
#
# 55900 天天初恋真美好
#
# 56000 感人
#
# 56100 加到五星只为给贝尔我所钟爱的贝尔不是蝙蝠侠也不是救世主是AmericanPsycho里的杀人狂是机械师里的失眠者是这部片里的斗士
#
# 56200 励志的故事但明显头重脚轻有种戛然而止的感觉贝尔真心演得不错所以加一颗星
#
# 56300 克拉尔丹尼斯演的实在是太牛逼了
#
# 56400 看了一半汗JR的身材真是火辣
#
# 56500 励志经典但剧情拍的还是有些乏力主旋律的调子太重
#
# 56600 我们都不是失败的人我们只是海洋饼干而已
#
# 56700 对昆汀的暴力美学还要慢慢适应啊
#
# 56800 无论是否真实剧本确实很棒JudeLaw0103年接演的三部片不断突破外形束缚剩下两部分别是毁灭之路冷山
#
# 56900 苦难永远是你成长的最根源的动力也是你走向颓废的最常见方式
#
# 57000 习以为常的心灵鸡汤
#
# 57100 很不错哦推荐
#
# 57200 Itcouldhappenedtoanyonebutheisjustsolucky
#
# 57300 山姆加入魔界小分队之前的人生经历
#
# 57400 少年当励志
#
# 57500 2003315cctv6
#
# 57600 真正的和谐不是河蟹泰坦队的出场舞太有爱了有点感动配乐相当不错39
#
# 57700 NICE
#
# 57800 冲着ClintEastwood导演和达蒙哥演技下来看的看过的第二部以橄榄球为主题的励志电影说励志也不恰当剧情电影吧体育题材很能挑动热情但是同题材的周末午夜光明很明显高明太多了
#
# 57900 不怕失败就怕被自己打败努力肯定会成功的
#
# 58000 我还是更喜欢光荣之路更多一些
#
# 58100 超煩那些小女孩
#
# 58200 爸爸好可爱咩
#
# 58300 开场可以给五星本来是以为大家一起来决战的结果好多经典人物都是酱油后面又陷入了比较老套的主角单打独斗的剧情由于酱油扣两星3星
#
# 58400 很无聊啊人物刻画也好故事情节也好歌曲也好
#
# 58500 时代变了迪士尼的真爱不再是王子和公主了
#
# 58600 任意门好想有任意门
#
# 58700 看美国动画电影真的有些看腻味了飞屋里的老爷爷里约里的母鹦鹉疯狂原始人里的女主人公驯龙高手里的男主人公等等甭管是人还是动物其价值观几乎都是一个模子刻出来的性格也是大同小异所以原本不想看超能陆战队来着但看到身边的人都在说大白又忍不住去看了
#
# 58800 那只总是流口水的狗把我笑死了希望富人不要买这些热带鸟类啊让它们留在森林里生活不是更好吗
#
# 58900 好评不差我一个
#
# 59000 单纯喜欢那只追逐松果的松鼠
#
# 59100 松鼠是主角
#
# 59200 萌到肝颤啊阿宝和鸭子爸爸之间的互动太有爱了沈王爷其实挺可爱的啊
#
# 59300 电影比女主角的胸还难看两星都嫌多
#
# 59400 就算世界无童话笑了哭了爱过恨过然后继续过
#
# 59500 心是孤独的猎手建议逃离所有的人找一个地方自己安静的看一点都不适合集体观影两个人都闲多
#
# 59600 乱七八糟其实
#
# 59700 导演是一个关注阴毛和打手枪的纯情男子
#
# 59800 in55w
#
# 59900 感觉很不错的一部片子
#
# 60000 卡片人生
#
# 60100 其实是两个人生观的斗争直男电影
#
# 60200 这片为什么评分这么高这和极速蜗牛有什么区别
#
# 60300 奥斯卡是有原因的
#
# 60400 整体老套而平庸人物也太简单了些演员不错
#
# 60500 失控的LEO和霍华德休斯
#
# 60600 没啥感觉一般般
#
# 60700 杰出的存在似乎总有着宿命般的悲凉与无奈只留给世人无尽的唏嘘感慨上帝派他将最美妙的旋律带往人间人类却用虚荣与嫉妒的原罪亲手将这份来自天堂的恩赐摧毁他离开人世时穷困潦倒长眠之处甚至没有一块墓碑只能租借棺椁搬运尸骸与贩夫走卒在同一土坑中被污泥掩埋
#
# 60800 给五星因为剧情
#
# 60900 挺吓人的剧情也很流畅五星推荐
#
# 61000 里面有彩蛋
#
# 61100 兄弟温情
#
# 61200 找时间再回味一遍的电影
#
# 61300 在餐馆打工的时候看得我好心酸
#
# 61400 生活总是在继续而我们一直慢一拍跟不上父辈们的脚步到头来又隐隐约约变成他们的模样才恍然大悟地遗憾起来
#
# 61500 总是很细节的日本电影
#
# 61600 三八节观摩
#
# 61700 如果真要用大师来框定许鞍华的话这部作品同天水围的日与夜当仁不让是双璧之作通体朴素浑然天成大音希声不多废话看似搞笑的场景也都是日常人做得出的同时又是非常到位的地理与历史意义的明确指向真是好太到位
#
# 61800 subtleandpoignant
#
# 61900 最后一家人在台上肆意张狂时我相信大部分人都会唏嘘不已我们的人生生活与生命到底因优秀而成功还是因平庸而独特是因平庸而失败还是因优秀而平庸呢
#
# 62000 温暖而让人嘴角向上的作品适合劳累沮丧兴奋嫉妒愤怒痛苦歇斯底里浑浑噩噩一夜乍富任何情况观赏
#
# 62100 噱头大于内容给四星只是感念于导演12年的执着不过这真不是我心目中的好电影120分钟以后只是在想怎么还不完啊美国家庭的平淡生活流水账根本让我产生不了代入感也许美国人会产生自我投射不知中土文青跟着激动个甚
#
# 62200 很不错就是我不太喜欢这类型
#
# 62300 国产佳作
#
# 62400 张静初很美很安静
#
# 62500 哎系影系影
#
# 62600 很多场面都是经典
#
# 62700 蝴蝶效应百年后必成经典
#
# 62800 很不错女主角好喜欢
#
# 62900 这是刘忻演的最好的一部了造型台词气场全程在线也没出现说话一用力台词就崩了的情况毫不客气刘忻就是这部片演技最好的也是最大的亮点
#
# 63000 女人不易不是汉子都抓瞎预告片很好看走着
#
# 63100 想不通我为啥买票进了电影院好了你们可以嘲我了
#
# 63200 我靠简直浪费我的时间
# 63300 套路没什么意思
#
# 63400 唉无话可说
#
# 63500 虽说剧本并不是烂到不能看但是你找个ZCSZHCHSH都不分的男主角我实在是听不了没打一星是因为看这部片子顺便见了一下闫妮本人大晚上的电影人到处宣传也是辛苦
#
# 63600 剧本一般遍布套路导演能力有限很多段落衔接不畅人物的情绪转折也有些莫名其妙由棒球少年的成长切入讲的其实是香港的改变基本上保持着一贯的对现在时的惋惜伤感和对过去的美好怀恋跟香港电影现在时是一个毛病躺在政治寄情的泛滥怀旧里忘了热血是感染力不是目的地
#
# 63700 前段較為蒼白急進後來漸入佳境智叔表現無可置疑林9的聲演也非常搶鏡當然我還會覺得此部電影算是好看但其實並不什麼出色及令人有較深層次的感受誠意可以還算地道但切入近來常提的本土或政治之類還是想太多了反之舒發情懷懷念逝去的時光還可以又或者是令我想起香港製造或戀愛起義之類會較為合適
#
# 63800 三星半有阳光灿烂的影子故事本身写的好喜欢董子健的演技日后必成影帝啊
#
# 63900 除了不知道导演想表达什么以外还好吧于是找来原著很短的一篇儿童网络文学误读顿时觉得还是电影好看点儿
#
# 64000 后半段有些拖沓但也是惊喜之作金像奖周秀娜可以争影后了
#
# 64100 其实说烂片有点过但是前排一溜打四星的你们没逗我很套路的片子或许不能说不真诚但是太普通了没有任何新意和亮点小清新热血感动这些元素都有可是不深刻简而言之就是好普通
#
# 64200 没看过原著整部下来没有什么吸引我的点中规中矩
#
# 64300 这种青春片也是醉了没有起伏高潮自认为聪明的反转也只能呵呵了
#
# 64400 出卖灵魂永无尽头
#
# 64500 最不想承认小时候曾经看过郭敬明和饶雪漫的书
#
# 64600 被剪了好多
#
# 64700 什么鬼
#
# 64800 怎么说呢不能算差但是要当电影就真的还需要学习啊
#
# 64900 乱不过看着不困原来的喜剧来个悲剧式结尾女主还是成了AV的女主这种绿帽情节也就给这部片子打了个大折扣
#
# 65000 配音好生涩看的时候一直觉得演员们说话大多有较重的安徽口音一搜才发现原来是合肥拍的本人芜湖人小桃好漂亮所以多给一颗星
#
# 65100 有没有发现导演长得好像潘长江
#
# 65200 猪哥亮主演很好笑啊闽南语歌曲串烧结局也不错
#
# 65300 超级大烂片看了烂眼睛和王宝强的那个什么杰宝科幻片有的一拼
#
# 65400 艹就懂得卖肉念台词像呻吟一样恶心啊
#
# 65500 可以理解旅行和人生一樣有時會遇到一段意外發生了情不自禁的邂逅然而明知自己是同性戀已決定要娶有身孕的妻子了還刻意去撩人把人掰彎後更不負責任地走掉無論當下再怎麼美好這種行為都很令人不齒男主也傻明知是未婚夫還投懷送抱盡管是步調緩慢唯美盈盈的同影男二依舊渣
#
# 65600 不如永远的零但还是有基本的水准的只是鸡血打的太多而且活生生的把一个商人搞成了民族主义斗士了
#
# 65700 前半段与自己的青春期吻合度为90但50分钟开始我的青春就断裂了也尚未给我一种心情去衔接我的梦想后半段节奏主义画风一变再变凌乱跳跃不知所云与全片风格完全相悖的荒诞式结局露出的只能是一篇潦草作文刻意美化的结尾若非前半段两星都勉强
#
# 65800 每个人的青春期都有一个初恋长大以后初恋的样子也许模糊也许记忆犹新我们最好不要去触碰她就让她在我们的脑海里还是理想的样子
#
# 65900 偏爱台湾的青春片被之前的很多部打动过可惜这次蛮让人失望一样的校园热血考学和恋爱可突兀的情感转折却始终没有代入感用电影里形容咖啡的描述就是过甜的卡布奇诺没有回甘
#
# 66000 影片毕竟是爱情片为主体主线剧情关注男女主的地位悬殊的爱情整个过程不能免俗整部电影充满了许多人生的无奈是时势使然人无法改变环境只能被时代所改变只是结局还比较理想主义基本上每一个年轻人都得到了自己想要的结果或许这正是那个时代的机遇与魅力你都已经无法再失去什么何不大胆的去追求
#
# 66100 我跟孩子都喜欢这种题材的3D动漫电影上映了去看看再来做个好评吧
#
# 66200 虽然剧情比较浅薄但还朴实台词虽然基本是叽叽喳喳的但还有趣剧中女主也挺可爱的还算可以的青春爱情片
#
# 66300 买了百合的虚假安利欺骗感情管虎的老炮儿拍得这么好结果这部让我挺失望的高群书之前还拉联盟喷烂片也不看看自己拍的什么鬼
#
# 66400 谷阿莫6分版偶像剧不扯淡已经完全演不下去了
#
# 66500 恶俗像三级片
#
# 66600 中规中矩终于等到的爱情总是感人
#
# 66700 二流的作家去拍三流的题材得到一部九流的烂片
#
# 66800 加长MV
#
# 66900 明明是很地下独立气质的电影却选择了在院线上映可能就跟最后字幕一样是还给成都的一笔债很情绪化的一部电影大量符号元素注定了受众不会太广天仙虽然美可惜腿是短板好几场恋足镜头最后呈现总是差点味道配乐太神了能进年度国产前三可惜剪辑用得乱七八糟白瞎了窦鹏的配乐
#
# 67000 真心不错的文艺片在如今的电影市场算难得的
#
# 67100 看了简介就不开森你们眼中的大学就是满满的荷尔蒙吗
#
# 67200 把冯唐的文拍出网络写手味好辣
#
# 67300 被偷走的100分钟
#
# 67400 大多数烂片都是屎味的巧克力味道虽然像屎但本质还是巧克力本片是巧克力味的屎虽然包装的像快巧克力本质却是一坨纯正的屎
#
# 67500 四娘为什么不改一改原著让幂幂在镜头前朗诵两个小时呢我敢说票房和现在比不会差
#
# 67600 脑残粉们考验你们的时候到了快来打5星吧
#
# 67700 屌丝逆袭女神真特么假
#
# 67800 超前点映北师专场千呼万唤终于见到周公子和张梓琳的闺蜜档真是最萌身高差电影平庸亮点少植入多迎合当下暖男风潮和当年的男闺蜜营销如出一辙待暖早更女们别再腻歪了暖一个人的才叫暖男暖一群人的是中央空调
#
# 67900 这个感情必须要有信任但眼前这人值不值得信任呢提出这个问题其实就是不信任这就是个走不出的闭环所以好多事情包括感情不是判断而是选择
#
# 68000 烂片哦亲
#
# 68100 组合完全没有CP感还有就是剩女之所以被剩下来真是有原因的先从自己身上找问题吧
#
# 68200 真实感匮乏夸张度又不足铺垫处不够戏谑高潮又不够动人总之是荒腔走板
#
# 68300 成龙继续吃老本几十年不变拍着类似的东西但比起十二生肖绝地逃亡这类妥妥一星渣片本片恢复了些水准有点成龙过去电影的味道迪拜追车很精彩另头一次没看到大哥很拼系列花絮台前幕后猛然鬼畜美丽的神话大跳印度舞连带片尾字幕整整15分钟结局不了了之
#
# 68400 标准龙式动作喜剧成龙大哥和他的美国逗比基友囧遍大江南北上演中美蒙俄版欢乐喜剧人最后真相属于无厘头脑残反转
#
# 68500 感觉贾乃亮的演技好尴尬
#
# 68600 没有负分可打killtime神作
#
# 68700 和跑男大电影一样坑赵丽颖真的好土
#
# 68800 真是恶俗下三烂让人感到恶心徐峥真是矫情猥琐出轨男还要装白莲花后面还有万万没想到和恶棍天使两部大恶俗烂片此类型和青春狗血电影并列国产电影两大毒瘤并且票房还不可思议大爆只能说中国傻逼太多
#
# 68900 一部喜剧电影好看就够了有些人痛骂说段子荤也许他们内心圣洁到性冷淡
#
# 69000 谁是整容前
#
# 69100 傻逼电影
#
# 69200 三观不正郭采洁有成为烂片女王的潜质
#
# 69300 小宝宝好看就是头有点不正常的大
#
# 69400 盛名之下无虚士和传说中一样差奢华拍得不如小时代好看剪辑神逻辑不如富春山居图颠覆搞笑不如情景喜剧放得开思想比公知浅薄那么一点社会批判性不如李大眼煽动片名意思是这是导演编剧订制给每个观众的夹带私货精神文明说教短片集总有一款教育你你看我们多深刻
#
# 69500 也就一还可以
#
# 69600 轻松的搞笑片
#
# 69700 彭浩翔最棒的一部很久没看过这么流畅没有死角的电影了一切都很好也很开心突然不再讨厌臭流氓彭浩翔了
#
# 69800 三星半真的不难看尤其前一个小时很有趣虽然有人说人品即作品可是为了周迅等演员去看也是值得的毕竟电影是个集体作业客观冷静看待吧
#
# 69900 一星给范爷的造型一星给倪虹洁的方言
#
# 70000 题材不错演员不错导演掌控力太弱可惜了
#
# 70100 智孝为什么要拍这么烂的片片酬那么高吗吴有利好久不见
#
# 70200 快枪手之前的定位是污力涛涛但当男主人公小庄飞檐走壁的那一刻我就看出了导演和男演员的野心他们一定不止想做一部骗钱的小成本电影而是有态度要表达很感动随后主角配角登场主角团技能满点狂开金手指确实有那么点抗日神剧幸好导演把多骨诺牌码的够齐整轻轻一点手到擒来
#
# 70300 你狗演技可比给zyt做配那会儿好多了快餐电影故事说完整了有头有尾其实我真觉得还可以一星这么多搞得我像水军好吧四星一半给你狗的大长腿一半给zjc的水蛇腰我真的不是水军
#
# 70400 大咖真的好多大鹏很用心进步空间还很大继续努力
#
# 70500 林熙蕾不去做T可惜了
#
# 70600 电影不应该像小品那样靠段子咯吱人一切都是扯淡的电影一定没有戏剧冲突
#
# 70700 发哥好老啊但还是帅
#
# 70800 黄百鸣儿子真不会编剧帅哥美女探案冒险高颜值中港韩黄金组合钟汉良嬉皮笑脸胡闹赏金猎人各自绝技取胜但翻车爆破是要谈情说爱到处生硬滑稽缺乏逻辑和细节为闹腾而闹特可惜那么多打斗飙车戏
#
# 70900 唉
#
# 71000 宋茜也能演电影
#
# 71100 烂片
#
# 71200 给陈伟霆的星星配音有点违和这么多师兄师姐助阵不错韩国女主什么鬼
#
# 71300 吓得我粉丝滤镜都裂了那件疯狂的小事叫国产电影
#
# 71400 看过乔杉的大保健男神和快递小乔还有煎饼侠里有点娘炮的经纪人这部电影里乔杉完全换了一个打法胸口纹了二龙戏珠带头和无良老板讨要工钱但其实只是一个想要救女儿命的好爸爸乔杉的戏路真心宽演技没得说更喜欢他了
#
# 71500 剧本设置一般拍得也没什么好说的不易的是有几处竟然让我笑得挺开心笑料加一星
#
# 71600 美女真是美啊听到山寨任贤齐已经要结婚了那伤心的嘴角颤抖的心疼认识任贤齐这么多年还是被这个山寨的拿着吉他的给骗子李若嘉扮演过迎春真是美女清纯美男主是翻版任贤齐模仿秀吧
#
# 71700 5星不为什么看海报嘿嘿
#
# 71800 片头觉得可能还有点意思后面拍成屎了
#
# 71900 甭星座了好不别欧巴了好不
#
# 72000 人类好累
#
# 72100 歌剧蝴蝶夫人片段httptcnhbAped
#
# 72200 大友那个最棒
#
# 72300 手冢最高
#
# 72400 还好吧公爵长得像邵某人
#
# 72500 原来是你干的少佐
#
# 72600 那个limitcycle看懂了的都是神经病
#
# 72700 35星四舍五入
#
# 72800 赞到爆带劲
#
# 72900 画风有张力
#
# 73000 掌女孩找猫脸上星星
#
# 73100 很特别的画面风格
#
# 73200 画风很帅故事有点单薄最后的那个镜头是表达对革命的怀疑么
#
# 73300 空境大爱泡MM果然需要耐性黑桐你是人生的赢家
#
# 73400 吾王
#
# 73500 干也你个死圣母
#
# 73600 好欢乐的番外临也君果然隐藏着某种神秘的力量足以与小静抗衡门田四人组道出了该剧的真谛这些全都是爱啊
#
# 73700 我看影讯影人电视剧排行榜分去吧
#
# 73800 四月一日君是百目鬼的呀再不成也该是座敷童子的呀怎么可以是侑子大人啊
#
# 73900 正篇都快忘了才看剧场版总算是前因弄明白了第一首ed真好听
#
# 74000 kami一般的美羽和伸惠
#
# 74100 yui酱无敌了
#
# 74200 好好地收了个尾还是很给力倒是感觉做得有些马虎啊前半部的省略剪辑不要太过分啦
#
# 74300 一如既往的美
#
# 74400 剧情太矬了
#
# 74500 卖萌
#
# 74600 嘛我好像比自己想象的更喜欢电磁炮啊第二季快来的更猛烈些吧
#
# 74700 在押井守手下变成政治动画攻壳feel内涵
#
# 74800 四月一日和静到底会不会有发展呢好期待呦
#
# 74900 法伊
#
# 75000 果然短发对式来说是必要的
#
# 75100 初中的回忆
#
# 75200 又重温了一遍你是不是奇诺取决于你的行为
#
# 75300 作画很良心然后就没有然后了
#
# 75400 绪花那青涩的少女情怀才是整个花开伊吕波的灵魂
#
# 75500 沉迷于游戏电影甚至小说没什么用因为真相和快乐不可兼得
#
# 75600 我怎么觉得以前选过
#
# 75700 尾田干得还不错虽不深刻也算轻松愉快
#
# 75800 服装秀高科技秀
#
# 75900 凤凰院凶真的消失
#
# 76000 124
#
# 76100 用很大的背景讲了一个很小很温馨的故事欧美人大部分少这种兴致
#
# 76200 画得真好看
#
# 76300 欧洲动画从不缺乏精品
#
# 76400 奇思妙想
#
# 76500 除了部分音乐看不出它经典在哪
#
# 76600 beyrself
#
# 76700 我在伊朗长大中的母亲在女儿结婚的时候哭着对女儿说我一直希望你长成一个有学问有阅历有见识的女人而你现在是21岁然后就结婚了我突然觉得如果我在40岁以前结婚我估计也会这么哭着对自己咆哮的
#
# 76800 杰作SylvainChomet的动画默剧风格跟这个剧本真是天作之合完美的致敬电影院里放Mononcle那个段落我看得都要跳起来了
#
# 76900 x
#
# 77000 敍事很平淡覺得有點悶
#
# 77100 挺喜欢台湾配音版的那女生的声音真好听那淡淡的爱情感人啊啥时候我也去乡下看看
#
# 77200 画面啊画面
#
# 77300 无爱
#
# 77400 剧情太狗血画面太重口
#
# 77500 删了那么多还能刺激到我泪点宅社你赢了
#
# 77600 这剧情是有bug的吧是有硬伤的吧我喜欢的那两个人哦悲剧了
#
# 77700 剧情仍然如当年一样脱线速水的关西腔有爱
#
# 77800 啧
#
# 77900 没看过TV版剧场版开头还是不错的再有就是圣星的炼成那段也很好看缺点还是情节老套啊2013410万象
#
# 78000 牙达我不承认这种ending绝对牙达
#
# 78100 还行
#
# 78200 6分动画效果很好延续着之前的2D3D风格故事就是低幼版的EVA加黑客帝国再加丧尸再加心慌方东拼西凑乱七八糟
#
# 78300 日本的动漫不服不行
#
# 78400 2009050420年前的动画啊素质却是相当的高只是剧情在今天看来的话就显得比较老套了
#
# 78500 补完的感动
#
# 78600 官方自带秀恩爱不厚道
#
# 78700 影片中段那超长的抑郁气氛是怎么回事
#
# 78800 不管是画风还是内容都是可用来追忆童年的美国动画感嗯包括内容阳子那角色果然是菜w是说就算追新版猎人那么久我还没习惯那声二代小姑娘OTL
#
# 78900 怎么说呢远达不到完美的动画但一如既往地令人舒心嫁人当如茉莉香娶妻当如茉莉香我大香哥一统江湖千秋万代
#
# 79000 2016年度最佳mv
#
# 79100 比起第26分钟的第一回感觉感动一般一个小时的尴尬长度也使得整个片子的丰满程度打了折扣但是众筹电影这一话题结合国内的大鱼海棠感觉确实有得一写
#
# 79200 时尚与魔法一起去旅行吧
#
# 79300 莲酱哦我感觉也要面瘫控了真是
#
# 79400 刷新了我这里的烂片记录
#
# 79500 这植物人其实是一个强大的易形者片末终于修炼出了绿之视野成为了传说中的绿先知但随后被郭傻子射掉一个分身后续故事敬请期待射雕英雄传
#
# 79600 赵又廷尤其二逼
#
# 79700 合格的动作片时长和剧情的转折让我觉得好像宝莱坞的电影呀国际片的路线赵又廷的演技有硬伤黄渤很好的转换角色搅基的搭配真是现在的主流呀全片没有惊喜也没有十分出彩的地方爆米花味道还算不错啦
#
# 79800 这种破东西一定要Mark一个台湾电影
#
# 79900 这么烂的片居然还有2和3
#
# 80000 看枪版已足矣
#
# 80100 我只想看原汁原味的港片两岸三地还有黎瑞刚都是什么鬼片尾想拔高立意但怎么拔都拔不起来的赶脚啊orzzzx追车戏还不错
#
# 80200 罗老板这部出品人监制编剧导演一肩挑的电影在摄影和美术风格上都与罗守耀他过去的作品相去甚远除了演员其他都很烂主题不明老当益壮不能这样不负责任地表现过于平铺直叙缺少矛盾点节奏更是硬伤再加上毫无节操的剪辑和配乐都无语了
#
# 80300 八十年代片
#
# 80400 烂片嗷
#
# 80500 硬桥硬马是我的菜三场对决一场比一场精彩打得肉好疼之前看精忠岳飞才知道刘承俊的那一身肌肉真是太棒了和四个铜人桩的试练拟人化想当精彩不光斗力也斗智真不错品出点止戈为武的味道
#
# 80600 阿发当年没选对经纪人实在不该接这类白痴猎奇片
#
# 80700 老实说我觉得这个还行为什么被放进烂片list了呢
#
# 80800 假
#
# 80900 你知道他上一部为了一头大象杀了多少人么无知的人类啊
#
# 81000 越来越垃圾
#
# 81100 嫩
#
# 81200 请问两个不死人的对打谁想看扯呢吗三星完全是看在Forlani面上
#
# 81300 我喜欢舒淇
#
# 81400 完全没智商的电影逗得不行关键这个导演也没靠谱过
#
# 81500 周杰伦像孙悟空一星刘畊宏串糖葫芦一星袁烈钢铁文胸一星
#
# 81600 一部影片讲了两个故事内容能饱满的了嘛还有醉拳打得像街舞黑龙江省的人都操着一口山东话要不就是天津话剧中煽情部分完全没有表现出来哎就是景色还可以
#
# 81700 x
#
# 81800 很一般的情感功夫片
#
# 81900 帅哥美女垃圾电影
#
# 82000 一开头就一个大穿帮就看俩主演耍酷中国女有点意思
#
# 82100 跑酷挺帅
#
# 82200 麻痹实在看不下去了
#
# 82300 一般吧
#
# 82400 不爽呀刚一投入就停了以前看过没印象了
#
# 82500 事实证明能把这片看完一定是眼睛被翔糊住了
#
# 82600 这类的电影都差不多不过看起来很爽
#
# 82700 真心不好看
#
# 82800 死法高端
#
# 82900 米高梅倒掉邦德已经不是邦德了
#
# 83000 C看到王珞丹和唐嫣都演起了好莱坞大片我十分的欣慰
#
# 83100 电影三星女反派毒蛇身材再加1个
#
# 83200 比空乏的剧情和泛滥的特技更让人生厌的就是美国强盗式的文化灌输了
#
# 83300 感觉比123部加起来都屌
#
# 83400 首先是看爽了然后是看累了特效也不能这么玩啊前一个镜头还没回过神下一个镜头就来了一个接一个所以到最后干脆麻木了剧情什么的几乎没有剪的也乱七八糟反正车子们打起来也毫无章法的那就干脆狂轰乱炸吧广告植入也赤裸的令人发指
#
# 83500 这片子从头到尾居然讲了个这么无聊又老套的故事根本谈不出个精彩之处
#
# 83600 芭姐你需要吗带个假发丑死了第二部就是和最新一部蜘蛛侠一样给儿童看的
#
# 83700 杂糅太多元素之后有些平庸硬汉之后慈悲之前
#
# 83800 中规中矩
#
# 83900 1星给LOLI
#
# 84000 乱七八杂感觉每过20分钟就换了个导演而且动作戏又少
#
# 84100 杰森
#
# 84200 以暴制暴乃杰森斯坦森真谛
#
# 84300 就结尾还行
#
# 84400 杰西卡没怎么表现啊
#
# 84500 10outof5pleaseHello这么低分到底是点解啊在众多蠢到不行的特工剧本里这个编剧可以写出这么多twists已经很厉害了Luke继pointbreak以后继续impress我成为下个MattDamon指日可待Acuteronetoo
#
# 84600 thegirlisbeautiful
#
# 84700 盗版祸害人啊
#
# 84800 纯粹怀旧哎
#
# 84900 满身肥肉还敢脱
#
# 85000 不能让我集中精神看的肯定都不是什么好片
#
# 85100 极限运动惊险特效全面升级刺激不已而原作细腻的人物性格和情感冲突的刻画面目全非连对原作经典动作的致敬都苍白不已可惜
#
# 85200 华盛顿最新力作
#
# 85300 什么乱七八糟的
#
# 85400 吕克贝松的恶趣味
#
# 85500 你要我的狗命我就要你的狗命
#
# 85600 卧槽什么鬼电影花了一大半时间讲怎么变神奇四侠结果boss就10分钟引出然后10分钟打败而且能力反转也太让人捉摸不透了没见stanlee然后全场干等到最后也没有彩蛋摔
#
# 85700 祝票房大暴死
#
# 85800 布鲁斯南总算演了回够狠的角
#
# 85900 T800
#
# 86000 面对异质的时候我们才知道谁才是异质那些晃镜用的真好
#
# 86100 吴镇宇非常出彩片子很有教父的感觉但有些场景和心理刻画比教父更细腻些很喜欢
#
# 86200 小孩儿太嫩
#
# 86300 太经典了喜欢
#
# 86400 第一次完完整整的看这部影史经典果然好看的没话说柔声倾诉的旋律一响仿佛又回到了高中时代那时候整天循环这些曲子大学的时候LOTUS经常三部连播从天亮到天黑一播一整天就过去了资料馆放映的版本不是特别好内嵌字幕太浅总会看不清
#
# 86500 真的很喜欢那个时候的杜琪峰啊
#
# 86600 那么之前打黄秋生是为啥
#
# 86700 从山头滚下来的箱子以及最后拿石头排人霸气的镜头
#
# 86800 极为一般看在twins的份上勉强可以看
#
# 86900 无聊之极
#
# 87000 管它什么DOA就是个烂片
#
# 87100 阿娇
#
# 87200 看完后唯一的感觉总算是完了
#
# 87300 李暉演的不錯
#
# 87400 黑珍珠般的女主挺漂亮的可惜红颜薄命
#
# 87500 从没坚持看完过电视一播这边我就睡着了
#
# 87600 唤回对警察故事的记忆
#
# 87700 成龍的巔峰作之一
#
# 87800 我一直在找那座边上堆满乱石的大桥
#
# 87900 高潮的不知所云
# 88000 打斗部分还行
#
# 88100 李连杰本人的配音实在是
#
# 88200 随便看看不好看而已徐若瑄还是挺不错的
#
# 88300 不合理啊不合理
#
# 88400 又一部被迫观看的电影香港传统无厘头手法与仿好莱坞大片制作的混血儿整体狗血得一塌糊涂还好有李灿森
#
# 88500 哎聊胜于无
#
# 88600 可以无语么
#
# 88700 金城武比较养眼
#
# 88800 刚看完回来挺不错喜欢大S和郑宇成我觉得和卧虎藏龙完全不像啊可能是配乐的关系吧
#
# 88900 坑爹的预告片武侠toosuck甄子丹装傻X汤唯入戏太突然金城武故作矜持最后的那个打不死的终极BOSS尽然是被插了避雷针给雷劈死的大家基本可以舍弃了
#
# 89000 评论就是哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈开始看豆瓣居然给这样一部商业喜剧片了8分以上还担心是水军但是看完之后真的觉得值大呼过瘾影院笑成一片实在是好看
#
# 89100 讨厌二货
#
# 89200 不想评论
#
# 89300 穿衣服没品的反面男一号
#
# 89400 第五元素中的娘娘腔成龙还可以的片子
#
# 89500 笑料生硬情节也有些牵强比第一部差远了
#
# 89600 白冰打的酱油也太酱油了安志杰很帅萝莉很可爱枪战还不错
#
# 89700 20140607幸福蓝海多了2黄1周的电影好像被打了大陆鸡血一样哪里怪怪的特别是这么碧池的结尾没钱没势人命在哪里都这么贱
#
# 89800 是谁令青山也变变了俗气的嘴脸是谁令碧海也变变了浊流滔天拖沓冗长为结尾加一星
#
# 89900 比2烂
#
# 90000 不值20块
#
# 90100 没有一个人的选角是符合电影本身的还比较能看的是血滴子被皇帝追杀之前的一段后面的剧本是请小学生写的吗
#
# 90200 春哥
#
# 90300 剪辑黑白正叙彩色倒叙电影开头和结尾都是主角在甩动照片注意照片颜色变化这个细节
#
# 90400 太混乱了医院里那个镜头很屌很屌值得买碟收藏一遍下来就基本看懂了佩服自己哈哈
#
# 90500 残酷的真相问号主义各种解不开的局
#
# 90600 看似支离破碎的镜头里却饱含着引人入胜环环相扣的剧情天才间的斗法从来没有输赢
#
# 90700 怎样把复杂的故事讲得生动精彩百转千回
#
# 90800 就像在看一首情歌mv每一慢镜头都那么美好就像学生们肆无忌惮的大笑却不知道下面开出了怎样的恶之花看完想说一句真是屌暴了
#
# 90900 剧情有漏洞但还是部好片
#
# 91000 细节合理性方面欠缺还是靠老一套的生猛来充实影片
#
# 91100 为了目的不择手段只有利益没有道德厚黑学看多了吧导演不敢深入探讨男主内心或许是因为男主的内心经不起探讨也就适合配合剧情展现一部中规中矩的处女作罢了
#
# 91200 你居然还没看过快去看吧
#
# 91300 搞了半天疯狂的石头也是抄的
#
# 91400 黑色幽默效果非常好小成本电影中的佳片
#
# 91500 后半段那叫一个啰嗦啊
#
# 91600 1给劲的音乐2神一样的镜头3牛逼的剪辑4西部片的致敬和牛逼颠覆5小李子颠覆的表演6吴宇森的致敬昆汀你是我的大神
#
# 91700 有人说这电影平庸大概是因为导演的学院派风格中规中矩在这个流行先锋的时代中规中矩都是平庸了
#
# 91800 我怀疑我的智商
#
# 91900 JenniferAniston看起来好老但是身材依旧很好
#
# 92000 库伯大叔
#
# 92100 看完之后有种啊似乎人生中没有这么醉一次有些遗憾的错误想法呢
#
# 92200 有几个笑点但是剧情太弱了
#
# 92300 最终还是独享黄色
#
# 92400 我觉得李冰冰打周迅那一巴掌是出自真心
#
# 92500 演技和剧情都不错逻辑上也基本可以自圆其说情节竟然有点像暴风雪山庄虽然路人甲的设定有点不公平不过在谜底揭晓前毕竟也给了人家镜头了在国产片里绝对算优秀的啦
#
# 92600 所谓心魔往往就是一念之迷其实只需在任一环节小小改变循环即可终止有话说人生大部分痛苦都來自于该离场时不愿离场的执著不过西西弗斯式的轮回看似一个惩罚一个永远沉沦万劫不复的诅咒同时却也是我们籍由一再面对相同的境况而学会和弄懂生命课题并由之毕业的唯一方式
#
# 92700 微妙变化很明显一点是在爱金属的哥们对自己的反应那儿洗
#
# 92800 某种类型片
#
# 92900 老炮儿我觉得好的东西都给人以共鸣比如这部电影老炮儿冯导演真是一个好演员最后放映结束纷纷有人鼓掌比起老炮儿更值得一提的就是小飞吴亦凡开场很惊艳没想到后面会有很大的转变吴亦凡让这个转变很自然说到底还是演得精彩
#
# 93000 身为导演的演员老戏骨值得称赞张涵予也非常不错有戏许晴抛开其余因素还是不错的吴亦凡演技提升很多演的小飞有他的存在感值得一看的电影
#
# 93100 吴彦祖其实是演技派只可惜长得太帅了
#
# 93200 看完这片子觉得他们那一帮炒股的人真的会愿意去做慈善我不信
#
# 93300 导演明显想搞成牛逼轰轰炫目华丽高智商牛逆转神结局的电影但是魔术不是魔法神奇不能玄幻装逼也得有个上限忽然发现魔术成为继精神病做梦幻觉之后悬疑片的新桥段whichmeans前面多匪夷所思也好后面完全不需要解释
#
# 93400 林德禄节奏把控紧凑细节也有铺垫酒后吐出初恋在船长笔中藏匿罪证U盘商业大厦调查围捕陈静对嗜赌如命大哥痛苦回忆仔仔冷峻杀手战乱记忆与柔情讽刺郭美美面瘫古天乐复读机般重复着ICAC查案不方便透露张智霖从懒散弱势到雷霆反击演屌爆但仔仔复活到爆头惨死没劲太拖后腿
#
# 93500 无法逃脱好莱坞的系列电影一部比一部差的命运对原著的改编也只停留在动机和旋律上人物形象塑造太刻板了毫无惊喜
#
# 93600 没去影院贡献一张实打实的票房我真是遗憾又羞愧
#
# 93700 当暴力开始露出锋芒来时理想就顷刻融化了
#
# 93800 不在电影院环境下能让我不间断一口气看下来的电影已经很少了此片算是优秀者线索埋得好情节扣的紧严正花痛失爱女时的哭戏好棒韩国犯罪片又回到了应有的水准高兴后30min还不忘探讨一下犯罪动机是否能够得到理解赞
#
# 93900 结尾值4星很好很强大薛景求
#
# 94000 韩式犯罪电影几近完美的一个综合展现无可挑剔不过薛景求先生这类片子是不是已经演了太多啦不过这不能怪你韩国人就爱拍犯罪片而且有登峰造极的趋势
#
# 94100 真是一对好兄弟
#
# 94200 8078
#
# 94300 囧和二还是有很大差别的这片子完全是拿二糟蹋了囧字剧情漏洞百出对话冷到犯贱众多配角打酱油都不会打卖腐吧腐点太寒碜卖狗血吧狗血又太假看到影院里观众还挺受用的真觉得鄙国人民笑点有够低看见刘仪伟的创意早就该不去的上了万恶的张小北的当丫给了4星砍死张小北
#
# 94400 为什么张超只打了个让人莫名其妙的酱油啊徐峥演技派折服还有那段关于2B的对话他们怎么就不笑呢
#
# 94500 除了交錯時空的敘事手法完全找不到亮點笑點都是硬擠的而且從現場效果來看也並不見得多密集袁泉那個做作勁兒快趕上白百合了馬蘇倒是意外亮眼景好構圖美配樂讚徐峥再用泰囧的方式演馬上也要面癱了這片別說比泰囧了瘋狂的石頭都夠不著啊只能比無人區好看點廣東人不懂你們
#
# 94600 拿无聊当幽默的邓长江和光彩暗淡的周星星做了一场法让难产而亡的人鱼帝国借尸还魂了另外星吹们适可而止你们根本不是真正的星星粉
#
# 94700 周星驰的电影总能让人看到他自己的童年和历史贫民窟长大的孩子变身成功人士依然视金钱如命可夜里却感觉孤独和寂寞直到遇到一个女孩这个女孩不爱钱和他可以一起快乐玩耍并且还爱他到可以为他去死于是他的孤独就好了披着环保的外衣讲了一个渴望爱救赎自我的故事
#
# 94800 这电影很多年前看的当时觉得一般
#
# 94900 接近三个小时的电影看到一半睡着了起来接着看德尼罗和阿尔帕西诺的对决老戏骨就是有魅力
#
# 95000 虽然必看但也就那样吧
#
# 95100 编剧该看TheSting一百遍
#
# 95200 帅哥再聚首
#
# 95300 群星云集亮点是两次爆破和mini
#
# 95400 这片子很好看的哎
#
# 95500 听别人说是很可怕其实还好
#
# 95600 好剧本
#
# 95700 剧情太牛逼了
#
# 95800 我想要不再害怕
#
# 95900 差点意思
#
# 96000 大片没有悬念
#
# 96100 没的说喜欢凯文史派西的表演
#
# 96200 很好看的片子诺顿演的很精彩
#
# 96300 一个大学教授不小心犯了一次性错误职业生涯和家庭生活被毁掉然后他就精心的构建了一个故事牺牲小我奉献给自己执着的事业编剧精心的编了一个我很震动但完全不感动的不现实的伟大故事一是这个片子的政治宣教色彩严重二是我个人不认同废除死刑三是为了政治目的走极端我无法认同
#
# 96400 演技无敌悬疑不足
#
# 96500 一票好演员共同奉献精彩演出剧本本身出色台词也写得精彩真不错的片子
#
# 96600 虚幻莫辨的现实阴暗的内核可以毁灭生活看完后变得更加坐立不安
#
# 96700 光碟借给朋友后一去不复返
#
# 96800 姐杀的不是人是寂寞Lee也说好看
#
# 96900 血腥到不行
#
# 97000 延续的导演一贯的美式主旋律故事情节类似于瑞恩一样的道德困境只不过将其用到了反恐平民之上最大的亮点在于战场临场感的营造声效剪辑非常之棒如果抛开政治立场不谈这片可以黑鹰坠落一起成为新千年直接对准战争的杰作
#
# 97100 5d2还是的影像弱了些确实实现了些不同的视角
#
# 97200 政治太正确了吧
#
# 97300 斯内普教授女王大熊小粉制片人还是脸叔这么强的班底还是换不来太多排片差点错过
#
# 97400 哦哦哦暗恰恰的背景中Tony的双眸很闪
#
# 97500 看的时候觉得机器人很恐怖一种对于未知的恐怖就像面对深海时候的恐惧一样因为你真的不知道一个机器人下一秒到底会不会干出超出人类控制的事情
#
# 97600 奠定了威尔史密斯的地位
#
# 97700 看了4遍还是喜欢
#
# 97800 2000年的片子
#
# 97900 还是很酷的
#
# 98000 特效
#
# 98100 为什么复仇者联盟的时候没有讲到thor和女科学家的后续咧果然和LOKI才是真爱
#
# 98200 碟二竟然是吴宇森拍的
#
# 98300 transformer
#
# 98400 点亮火把所有宝藏出现时被感动到了美国和任何其他国家都不一样他们选择了自己的体系和信仰也就更加热爱这块土地11232012withJoe
#
# 98500 什么玩意儿
#
# 98600 作为一个肌肉男jasonstatham简直是性感极品
#
# 98700 可爱的杰克
#
# 98800 这次他炸毁了一辆公车并在另一辆公车上安装了炸弹只要该公车的时速超过了50英里就不能再减速否则就会引起爆炸当杰克赶上这辆公车时公车已经满载乘客行驶在高速公路上时速也早已过了50英里
#
# 98900 小学在电影院看的大片之一那时候看这类片反正次次都能心惊肉跳为主角捉鸡不已
#
# 99000 恩
#
# 99100 英雄主义的意淫
#
# 99200 双旗镇里面住满了所有的中国人
#
# 99300 红豆妹妹
#
# 99400 这才是江湖该有的样子江湖哪有那么多浪漫只有血腥的不堪镜头晃的厉害迷离而困惑最后是我的眼睛太慢了20151205中国电影资料馆
#
# 99500 拷贝谍影重重但还是差了点常常是导演自己紧张的要死而观众却开始觉得审美疲劳了这类片子的剧本讲究信息量的释放步步为营的设局挖坑要求故事尽可能的简单用动作戏来讲叙事而且动作戏的激烈程度要逐步升级不断的制造景观韩国人这次只落实到了皮毛还差的远呢
#
# 99600 如果我说孔侑长得实在不够帅学元彬转型很难成功会不会被打
#
# 99700 有一种情感是跨越代沟两个孤独人的慰藉和相互温暖这种感情清澈纯真电影本身有着犯罪电影的冷暴力还有着雷诺的暖温情顺便也有着商业电影的剧情故事和耍酷的帅哥紧张情节下的温情回味一声阿扎西万千情愫
#
# 99800 当欲望混杂在了一起就注定要以悲剧收尾
#
# 99900 姜东元真是帅啊
#
# 100000 节奏太快铺垫少了些故事情节以姜东元展开就完美了
#
# 100100 还可以个人比较喜欢的题材
#
# 100200 时间剪短了这颜色也花了哈哈
#
# 100300 没有当年那种惊艳的feel了
#
# 100400 王家卫电影里的最爱阿飞演得最好
#
# 100500 世上有一种鸟从出生就没有脚一刻不停的飞累得时候就是坠落的时候
#
# 100600 她爱他
#
# 100700 很不错
#
# 100800 前戏是长但可以学着片子在现实中唠嗑高潮还是给力的
#
# 100900 有点墨迹
#
# 101000 暮光之城版的蜘蛛侠各种少年滋味让我想起那句诗少年不识愁滋味为赋新词强说愁
#
# 101100 特意去看了imax本以为都市荡秋千能有超强的冲击力可惜失望了骚版蜘蛛侠女主胖得配不上他啊剧情神马的就不谈了
#
# 101200 HIGH
#
# 101300 真是打不死的蟑螂
#
# 101400 马勒这是哪门子经典还没怎搞来就杀起来了史编太让人失望了
#
# 101500 好老的片子
#
# 101600 007里面相对比较喜欢的一部
#
# 101700 竟然是吴宇森导的
#
# 101800 我看过的最棒的恐怖片之一
#
# 101900 主角成名的那套电视剧也很好看只是碟市上从未出全过
#
# 102000 香港的黑色幽默也能丝毫不逊于外国啊
#
# 102100 笑傻了
#
# 102200 哎玛就是喜欢这样混乱无序不知下一秒会花生咩也事的片
#
# 102300 剧情碉堡峰回路转转得有点多了
#
# 102400 这TM是喜剧么小成本吧效果不错
#
# 102500 就像听到福尔摩斯片尾变奏的音乐的一样也许你会皱着眉头问一句这是怎么发生的但一切就是这么发生的不要强求故事的合理性只要在导演设置的人物网里看性格鲜明的他们把不可能演绎成可能就行了
#
# 102600 编剧太强
#
# 102700 笑点似乎比前两部少太多了这片子往浅里说讲的是拒绝长大往深里说是映射社会对人的同化蓝血丧尸就是被掌权者洗脑的中产阶级的象征
#
# 102800 其实这是部政治片
#
# 102900 一群衰人
#
# 103000 关于恶的故事
#
# 103100 公园里的电脑系统怎能一人管理是否也要有话事人
#
# 103200 完整的世界观很精彩
#
# 103300 第三部感觉有些不科学anyhow帅爆了
#
# 103400 如果不是诺兰和卡梅隆我可能会崇拜本片想象力还是没有放得开了说实话这种科幻程度远不及三体二流的科幻喜剧7
#
# 103500 甄子丹vs李连杰
#
# 103600 扣一星是应为坏人太早就出现了
#
# 103700 只记得父子俩那段对话很囧
#
# 103800 80年代警察片一改之前武侠片以武犯禁的做派引入现代执法观念将中国传统无数道德观念与现代法律意识结合到一起重塑正面警察形象坚定观众对法制的信心新浪潮之后曾出现一系列新入行的笑闹警察以幽默搞笑为主而这一时期的警察多为社会公仆的理性形象以成龙为代表的商业性质动作奇观
#
# 103900 随着时间的慢慢流逝故事尚可一看但武打场面仿佛陈旧了许多多亏李小龙的男人魅力一直支撑
#
# 104000 这剧情也太扯了
#
# 104100 第一滴血系列的第二部比第一部紧张刺激了不少感觉更像动作片了里面各种格斗技巧和战斗场面都变成了经典尤其喜欢那个越南反抗军的美女好有味儿
#
# 104200 只看最后20分钟也足够这部电影因为李小龙的过世已经不是它原来的样子至于死亡游戏原本的剧本和设计我们已经无缘看到只能通过最后那一点点画面缅怀一下这位巨星李小龙对中国功夫和华语电影做出的贡献是不可估量的
#
# 104300 也就这样了
#
# 104400 马马虎虎
#
# 104500 小时候觉得很酷
#
# 104600 亮点是有释小龙
#
# 104700 有点小二逼就是了
#
# 104800 当时感觉很好
#
# 104900 这个很好玩寻宝啊寻宝
#
# 105000 A计划算是成龙早期电影中蛮有名的一部成龙洪金宝元彪钱嘉乐
#
# 105100 利智还是张曼玉当然是选利智
#
# 105200 刘师傅宝刀不老经典之作
#
# 105300 成龙老了点不太和谐还以为华仔在前面是伏笔结果就是来打酱油的后边故事感觉很过场音乐不错故事逻辑与第一部接不上
#
# 105400 这个比速度与激情早多了袁咏仪有点搞笑潜质啊哈哈吊车抄家大闹游戏机厅成龙打斗电影很多经典场景
#
# 105500 就记得是个厨子
#
# 105600 小时候在舅舅家看过好多次
#
# 105700 拍的很好看得我好纠结啊
#
# 105800 以暴制暴
#
# 105900 上帝之城还是撒旦之城抑或上帝撒旦
#
# 106000 没意思主要是朱阳不喜欢看
#
# 106100 对现实世界就是证据就是一切最后那部分有点狗尾续貂没有结尾可以给4分的
#
# 106200 不喜欢的剧情
#
# 106300 前三分之一像水星领航员后三分之二像北斗神拳结局玩砸了另那菊花炸弹流了一逼
#
# 106400 警察局那段好精彩
#
# 106500 完全就是看朱莉的绝世神功故事情节神马的就是个浮云
#
# 106600 警队里的狗仔想起过去结局有点假
#
# 106700 徐子珊演得不错
#
# 106800 真心不懂
#
# 106900 豪情的荒漠温情的复仇人物饱满得无话可说到最后谁都会被那情感的暗涌所折服
#
# 107000 科恩兄弟居然拍了一部这么感人励志的电影nevermindtheending这片的摄影我好喜欢
#
# 107100 寻枪的各种巧合各种误会如有雷同实属巧合在夜色的衬托下各个人物和场景变得极有观赏性配乐少了些杜琪峰特有的轻佻和清高但仍不失水准人物角色丰满有灵魂林雪从窜怯怕焦急惧偷笑各个细节都演出特色配角不再是配角非常杜琪峰风格的PTU顶游乃海欧健儿
#
# 107200 够帅养眼就得
#
# 107300 意外的好看
#
# 107400 不错
#
# 107500 吴镇宇帅啊
#
# 107600 香港电影里集体出现的对回归大陆的恐惧84年签订合约身份的危机感也许就是从这部电影开始的吧这部也是最激烈最无法共存的一部吧
#
# 107700 挺俗挺烂
#
# 107800 又名EU冲锋队Chungfungduijinofohgaaitau导演陈木胜BennyChan主演劉青雲陳小春李綺虹黃秋生吳鎮宇張達明黃子華上映年度1996制片国家地区香港语言粵語imdb链接tt0126839
#
# 107900 要不要这么直白的片名啊金城武真适合演杀手
#
# 108000 9535版本警匪官僚97的港片
#
# 108100 有些挂羊头卖狗肉的感觉更像一部亲情片的另类警匪电影比较随意化的个人风格和不时的黑色幽默凌厉的动作场面都很容易让人在不知不觉中喜欢上这部片子不过尾声部分过于戏剧化使得好感度down梁山伯与茱莉叶也早点出2cd吧
#
# 108200 当年看卧虎藏龙时三场联播送的看的另一部送的是纪录片乾隆下江南印象中非常好我还在穿过陕师大的校园时向一个小姑娘绘声绘色描述了这个故事
#
# 108300 都是棋子都是浮云
#
# 108400 港式黑片至高经典
#
# 108500 身边的死神
#
# 108600 其他不说仅凭那首插曲就值五星
#
# 108700 赶得要死喜欢这个赵敏
#
# 108800 邱淑贞的小昭才是我喜欢的小昭
#
# 108900 或哟好看的吗
#
# 109000 4个小时的版本其实也一般
#
# 109100 TVCHANGSHA
#
# 109200 本年度最佳影片
#
# 109300 我更喜欢苗翠花
#
# 109400 呵呵狮舞还挺经典的
#
# 109500 这片貌似就徐枫一个女的打斗好精彩
#
# 109600 不我们是兄弟这儿看哭了人还是应当一身正气活在世上而不是当宅男食草男
#
# 109700 大卫哥还真是个阴沉脸
#
# 109800 镜头音乐和静中起变的节奏我都太喜欢了高雄的三场打斗结尾的杀招也很有特点死亡的美超越了古典故事和结构都没什么开头营造的宿命感后面也被剧情吃了ps郑少秋真的长得一脸坏相徐杰这个角色要是换个人演真是顶讨厌
#
# 109900 以现在的眼光看过去也许很不公平但是实在不能回到过去了是不是给三分吧
#
# 110000 有看头的全都是倪匡的那点恶趣味至于张彻那些依旧粗制滥造一无是处的陈腐美学真是没劲透了张彻说到底就是个拍B级片的还是那种经不住时间的考验的B级片还是一点不cult的那种B级片
#
# 110100 作为推理题材做到完全无逻辑也是不易动机薄弱线索单一揭谜过程就是一场催眠不用担心睡着了就会错过关键的推理过程因为根本没有设置多余人物不少除了拖戏没有别的功能所以整片松散冗长软绵绵原本觉得服化道还算精致有加分但是强做伪3D骗钱使视觉舒适度打折扣还是减一星
#
# 110200 这个张起灵我服
#
# 110300 其实还不错
#
# 110400 王珞丹烂片二连刷
#
# 110500 今年到处都是彭顺和彭发两兄弟的作品
#
# 110600 再一次挑战了广局剧本不错演员演的还算扎实毕竟是导演的第一步电影还有待提高
#
# 110700 对电影的原创配乐印象深刻冰天雪地里一直紧张感萦绕真相本身很好猜价值三观也没什么问题缺点就是跟人家一比不高深甚至不去作高深状生怕观众看不懂还用梁家辉旁白做解释为培养刑侦探案类电影内地观众做了最大的贡献就是他的题材敢于触及社会现实了
#
# 110800 续集我都想好了第二部叫威震天第三部叫惊破天
#
# 110900 剧情在哪里看到过挺山寨的
#
# 111000 带孩子看吧反正一般
#
# 111100 第一人称个卵子啊滥用硬核大战就没多优秀这俩电影加起来都没有2005年毁灭战士最后十几分钟的第一人称来的好12年不进反退的大失败
#
# 111200 为什么布兰登和张雨绮会接这种电影
#
# 111300 尼玛骗补要不要这么赤裸裸看的我只想说脏话
#
# 111400 剧情无聊中国元素特别傻angelababy演技可怕
#
# 111500 肯定会有续集博斗场面游戏感很足但是刺客背景描述很莫名其妙所以信条什么的就更摸不着头脑当然主演们演技都在线库泽尔的镜头还是一如既往的压抑他弟弟的配乐特别燃
#
# 111600 时间资源生命原浆地球牧场基因转世身份纹身皇室乱伦赏金狼人洁厕小妹M巾止血养蜂避世特瑞吉利姆客串于是硬加了五分钟妙想天开的官僚手续但这些都不敌脚踏滑板鞋救世的low逼设定XLAND
#
# 111700 还是很好看
#
# 111800 能不给星星么无以伦比的大烂片父女恋
#
# 111900 文戏糟糕武戏的视觉表现一流电影诸多桥段借鉴八九十年代香港功夫片配的生硬又亲切看罢导演简介出于私心加一星希望导演无畏嘲讽继续创作
#
# 112000 大侠卢小鱼好有代入感的声音
#
# 112100 不好看
# 112200 哎我以为是小时候那部妈妈再爱我一次的重拍版你们都打1分那我打5分好了拉平衡点
#
# 112300 做作乱七八糟一塌糊涂黎明无端端当什么导演
#
# 112400 看在黄轩祖峰段奕宏份上给二星
#
# 112500 白瞎了这么好的卡司这样好的题材剪辑的时候应该没睡醒脑袋打结神经错乱才有这种完全拎不清的叙事故事比白开水还寡淡人物的转折突兀毫无说服力不打一星的唯一原因是情结
#
# 112600 那个面试居然就没了
#
# 112700 我对邱礼涛涉及惊恐元素电影的喜爱依旧停留在香港90年代的阴阳路系列和人肉叉烧包伊波拉病毒最近几年也就一部青魇还算过得去大陆广电局的局限性削弱了很大一部分可能性像釜山行招魂那样的优秀片子不是国人拍不出只是广电局不让啊可悲
#
# 112800 半颗星好难看
#
# 112900 原来美国也会有科幻烂片
#
# 113000 还是不该看俄罗斯特效类电影
#
# 113100 卧槽还打算拍第二部等了一整部都不知道原因是什么
#
# 113200 我竟然看了片假的动作科幻片这编的什么跟什么呀各种半机械人纷纷登场整个世界只剩下几个三三两两的战士在与之作战血浆太少了吧射杀那么多人竟然一滴血都没有只用慢动作来加特效来糊弄观众这手切下来掉地上看起来像橡胶手道具组太应付了吧这制片没什么钱就不应该拍这样题材的影片
#
# 113300 具备了一切YA题材的反面特质
#
# 113400 当纯粹爆米花的电影看及格但看到结尾忍不住要来一句你还真的意图拍续集
#
# 113500 除了热依扎呀演得还行啥破玩意儿别有病花钱看也别等下映在家看浪费时间破玩意儿
#
# 113600 剧本3星演员4星影片1星有很惊悚吗唉浪费时间一点诚意也没有
#
# 113700 差在演员黎明游离韩彩英更游离剩下一个耿乐仍旧有国片那一套不知如何对戏9号密室里有一个不错的反客为主的故事这个电影里没有将情节写到极致很快就开始打打杀杀了
#
# 113800 真的烂本身选角就有问题黎明演这种人物一直在出戏逻辑bug一大堆无用设置超多真是个大坑还整个于娜来然后还得给人洗白这tm什么玩意卧槽这导演是老师的恩惠的导演片方真有钱请这么多大咖还整这么个破玩意
#
# 113900 剧本比较平庸人性没深挖悬疑部分不烧脑也有bug但能看到创作者的诚意全体演员演技在线胡歌的反派戏份不多但让人印象深刻眼神极为到位宋佳也不错给演员多加一星
#
# 114000 片名已剧透神经病组团彭氏兄弟的恐怖片真是江河日下一部不如一部本片无论从哪方面来说都透露着一股廉价的味道
#
# 114100 国产的悬疑片还真的需要多磨练
#
# 114200 其實拍得不錯
#
# 114300 文艺的生活片
#
# 114400 叙事让我想起卡佛的小说如果最后一镜停在空置的枪鞘上就更卡佛了不过那样的话只值四星这个结局显然更有力度
#
# 114500 好看
#
# 114600 命運的某種輪回與複合
#
# 114700 文本驾驭力太过强悍对白几乎填满了每个字幕牌间的场景指涉两岸政治文化圈社会阶级差异堆积交叉式并行的角色处理稳重而酝酿着冲突观感丝毫不乏味枯燥这一夜过后像更换了一个时代宣言式的剖析人物的内心角落入骨三分且醒世
#
# 114800 原來是侯孝贤的
#
# 114900 欣赏不了没故事慢慢慢慢
#
# 115000 从片子的英文名thetimetoliveandthetimetodie就可以得知影片试图探讨生与死这个宏大的命题但我们看到它的表现形式是日常的琐碎的侯孝贤用这个带有自传色彩的故事描绘出了时间的轮廓同时亦勾起我们关于童年的回忆
#
# 115100 走火入魔
#
# 115200 还可以吧父母之仇不共戴天
#
# 115300 这啥破剧本
#
# 115400 唉我不是那个年代的淫
#
# 115500 我就喜欢这样的科幻片儿
#
# 115600 第一部是最忠于原著的而且第一次接触魔幻世界很受震撼
#
# 115700 重温哈利波特一竟然比在电影院看哈七的夜场更加激动虽然剧情低龄特效幼稚但作为一个系列的开始它太萌太令人惊喜了所有人还是那么年轻令人唏嘘不已
#
# 115800 三星半前半段依旧是蒂姆波顿熟悉擅长的哥特风格后半段的高潮部分虽然也看得人激情澎湃却总显得有点小家子气然后就变成一部不折不扣的低龄电影
#
# 115900 很不错电影院效果也看
#
# 116000 再来个赵忠祥就齐活了
#
# 116100 原来这么有深度的可惜赶完图的晚上就去看太累了困死我了竟然睡着了罪过而且印度口音的英语真心是听不懂其实我到底喜不喜欢李安呢
#
# 116200 帅气的杰克船长
#
# 116300 终于正经盗墓了味道比较正几大主场景设计得相当漂亮美术太棒片子很好地完成了从概念设计到最终画面的转化3D效果很赞对我这种3D迷可以说是一本满足个别场景视效不够理想抠图素材跟背景画面融合得不精致棚内绿幕拍摄的场景也比较明显这有点遗憾
#
# 116400 多给一星算鼓励
#
# 116500 每天一杯迪士尼上班有劲了加班不怕了一口气都能做出10个PPT
#
# 116600 童话世界中的成人法则
#
# 116700 作为一个没玩儿过游戏的姑娘我觉得还可以不过前面比较难看懂玩儿过游戏的男票说觉得好失望
#
# 116800 没有任何特效的一部科幻或悬疑片影片开放式的结局让观众一直对此片争论不休就像这个男人来自地球一样你无法判断他是K星人还是只是个精神分裂者不过这些都不影响剧情给你带来的希望不管情绪遭遇再多的负面因素只要能看见希望那一切都总不算太糟不是吗
#
# 116900 很好很强大的电影么spacey乃神人也莫非也是双重人格PS感觉doctorPowell怎么像钢铁侠1里的boss啊
#
# 117000 硬cd3不流畅
#
# 117100 很深刻的电影人性无神论人类文明亲情
#
# 117200 1982年所以这差距不是说追就能追上的雷德利斯科特在这个片子里的思想跟异形是相通的造物者与被造者间的辩证探索与较量
#
# 117300 在第一部的基础上扩展了人物的性格片中几个主要的非人类外型演员很出彩很有喜感的一部
#
# 117400 当霍金说我们应该提防人工智能的时候大家都应该严肃地好好听着不管程序编的多好人工智能有的永远不是感情而是目的以及连我的手机都是指纹解锁的为什么片中的科技达人老板家的门还要刷卡才能进这不是留下隐患么
#
# 117500 因为塞缪尔杰克逊这部片子增色不少
#
# 117600 在那个年代算很不错了吧结尾有点基情呀当年他们都好年轻
#
# 117700 开始喜欢上VD了十年前的第一部跟5比起来不赖的
#
# 117800 到了第三部史泰龙已完全忘了第一部中通过一个退伍老兵对越战的反思继而体现的美国人对越战的态度
#
# 117900 00720蛮喜欢这个黑皮邦德女郎滴
#
# 118000 两个人要是太熟了倒不好意思再玩下去了也就是到了该散的时候了
#
# 118100 我是怎么迷上你
#
# 118200 共枕软塌迷离鸦片
#
# 118300 重看了一遍你睇斜阳照住个双飞燕斜阳落了燕子飞了什么是这世界上最坚硬的东西就是那些琐琐碎碎的日子平淡的愿望本来想写影评后来觉得想说的话也就这两句不必再多写了
#
# 118400 无聊的电影
#
# 118500 王祖贤我心中最美的女人
#
# 118600 太美了
#
# 118700 虚伪与谎言所有人都逃不开的人性但仍旧会存在着我们可以相信的人
#
# 118800 UAREBLACKEVENNOTTHEUSABLACKURDIRTY94年我在上小学看着电视机前安南出现都大叫大灰狼不会理解什么是种族复仇民族主义维和部队大使馆西方势力五国军火此片让我补到了我的无知和人性的惊人农业的胡图和养殖的图西一个比利时殖民时代区分人的标杆留下了一把战火非洲难民的确不好看如同白人看我们一样吧是不是沾沾自喜的同时心里也嘀咕两句呢红十字会女士没救成的一个女孩说我再也不做tusi了求求你们放了我00主题曲很好听
#
# 118900 狂热的集体是失意者的家园
#
# 119000 加速抑郁
#
# 119100 黑泽明的巅峰了此人只能拍武士片而且有几部武士片老实牛逼
#
# ...
#
# 219100 cutebutt
#
# 219200 傻得无趣除非你保持67岁的心态
#
# 219300 有时候胡闹就仅仅是胡闹而已
#
# 219400 YouTube上偶然跳到的好片
#
# 219500 父与子面对失去妻子和母亲的伤痛在一段旅程中恢复正常
#
# 219600 又一典型垃圾导演毁好演员作品
#
# 219700 独立小片jeff跳下去那刻燃了
#
# 219800 notbadinterconnected
#
# 219900 FuckthewriterFuckthehappyending
#
# 220000 其实故事还行放眼望去全是德尼罗年轻时的影子
#
# 220100 太淫乱虽说我腐我也不喜欢看这么大尺度的
#
# 220200 卖肉呀
#
# 220300 还不错颜值够看
#
# 220400 泰国电影不乏小清新很感动演员都很萌惹
#
# 220500 虽然平淡无奇循环式的叙述方式但给人要看下去究竟怎么回事的感觉看的当儿我总在等待最后突破口一个啊果然看下去是对的的理由海边两人的情景几个镜头重复数次穿插的错乱而意义不突出是想表达最初时的情景吧看到最后那个突破口还是没出现就一封信在最重要的时候电影结束了
#
# 220600 pc又名戏剧性的一切二分钟床戏未露一夜炮友炮到真爱字幕用心圣诞快乐被子不错颜值有限
#
# 220700 无对白部分和盲老师的水下镜头认真剪一剪可以打五星了故事其实可以索性不去讲然而从剪得像丧尸灾难电影一样的预告片来看投资方还是有点赔不起
#
# 220800 好烂
#
# 220900 没有看出来哪里有爱了
#
# 221000 国产动画加油ω
#
# 221100 有些傻逼老是乱评价我觉得还行
#
# 221200 剪不断理还乱的生活大小事物真叫人烦不胜烦
#
# 221300 说故事说的不周正的电影
#
# 221400 和去年安妮斯顿的那部蛋糕有点像给人感觉都是死气沉沉又没有任何意义又是一部讲述闲得蛋疼的美国普通妇女的中年危机的故事萨拉丝沃曼其实也不见得演得有多好只是突破挺大的打破了此前无厘头的女丑形象让人看到了她其实也可以正儿八经的演戏虽然在跳支华尔兹里她就已经证明了
#
# 221500 家庭爱情误会挫折最后大圆满都是煽情都是正能量喜剧效果不明显而且拍的挺水的是那种不用丁点精力就能看的电影
#
# 221600 虽然不是因为什么人品问题但还是想十分想省略掉所有男女猪脚的戏份实在演得是太烂了那个黎处长还勉强
#
# 221700 感觉这其实是个色情片夏雨这几年是中了什么邪哦第一次看关晓彤演戏真是完美演绎绿茶婊
#
# 221800 影片讲述一对幸福的青年夫妻和一对甜蜜的年轻情侣因为深夜的电台情歌两段情感发生了交会纯美的校园恋与激情的职场恋爱恨纠缠足以引发每位都市人的情感共鸣讲述的爱情就发生在普通的中国城市巧妙地以电台这一曾深刻影响几代观众的传播媒体为切口契合当下热门国产片的集体怀旧潮具有相当的话题性
#
# 221900 王晶稳定输出一年数次秀后宫
#
# 222000 为了周秀娜啊居然看完了
#
# 222100 谈梦想是很尴尬的可是为什么杜汶泽会突然跳进去没搞懂拖钱拉债的结果就是弄了部烂片里面的人物没有一个有记忆点
#
# 222200 重口味的外表下有颗小清新的心
#
# 222300 呕
#
# 222400 烂
#
# 222500 这不还算不错熊黛林长得还真是难看
#
# 222600 香港喜剧就这样
#
# 222700 没有最烂只有更烂
#
# 222800 哈哈吴君如好好笑
#
# 222900 还可以
#
# 223000 吴克群是不整容了
#
# 223100 编剧敢再无脑一些吗
#
# 223200 确实比较搞笑但是郭采洁长得好像范晓萱
#
# 223300 净扯犊子
#
# 223400 跳啊跳真没感觉
#
# 223500 羊便秘了牛就开胃了
#
# 223600 虽然没报多大希望但也没想到原来是这么烂的电影人家的情侣档都有声有色这两口子
#
# 223700 看完电影好想有一个这样的手机
#
# 223800 哇咧第一次看到跟国产偶像爱情电影有一拼的日本电影哟
#
# 223900 演员都挺喜欢的但是剧情比较一般
#
# 224000 工桑和愛麗絲那無聲的故事看淚目了
#
# 224100 不错哟
#
# 224200 希望有一天能看到少女漫中每一个装模作样的梗剧中人都能自己把它嘲回来
#
# 224300 莫名其妙男女主太好看还有那段商场的歌舞拍的很漂亮
#
# 224400 虽然中外合拍拍的片子比较垃圾但是呢演员选的非常不错倪妮演的不错但是游艇一般般
#
# 224500 心旷神怡的北方靓丽景色配以清新空灵的音乐带有些许凯尔特风格仿佛一场身临其境的冒险一首永远住在人们心中的童话传说
#
# 224600 前面简直无聊愚蠢的要死要不是技巧和第二幕开始的明确的动作线这应该会是烂片不得不承认成熟的技巧还是稍微掰回了这部电影三星给影片质量但并不推荐观看
#
# 224700 连真鸽子都舍不得用还用5毛特效几个司机驾照买的吧人家悟空可是站在斑马线上呢这妖精的脸和脖子色差真大
#
# 224800 没有字幕看完了也是佩服自己小男孩和那头猪挺好玩的不过好像价值观有点扭曲
#
# 224900 都发福了岁月啊
# 225000 就是一救孩子的故事而且最后神兽还自己把孩子救上来了那你找别人帮忙个鬼啊还有为什么族长突然会飞了他在救孩子的过程中领悟了什么就会飞了完全没体现啊雨果通过这事有啥成长吗要是关于亲情那父女俩本来关系就很好啊完全没啥突破或修复什么的就展现了一下父爱这片到底想告诉我什么
#
# 225100 很好看我儿子超喜欢
#
# 225200 25不烂只是剧作牵强还好表演没有跑太偏
#
# 225300 节奏把握的还不错基本上是靠范伟和乔杉撑着大鹏中规中矩张天爱没什么存在感倒不如打酱油的邬君梅柳岩的脸太假了结尾太扯淡了用电影里的一句话你拿把假枪指着我不觉得荒唐嘛
#
# 225400 毋庸置疑这片子是用来洗钱的
#
# 225500 剧情不用吐槽了少拍这种电影吧老何
#
# 225600 张子枫未来星途不可限量但是这剧情你确定不是照着初恋这件小事来的请来点自己的创意好吗PS看完片子才知道高估了编剧它是照着初恋的台湾版我的少女时代来的
#
# 225700 值得回味的一部影片想起了学生时代的我们
#
# 225800 像是一个家庭安保设备的宣传片因为除此之外真的看不出这电影到底要干嘛
#
# 225900 故事创意不错剧情推进过于缓慢马东锡这个村民太城市痞气了
#
# 226000 意外警察不是坏人一伙的
#
# 226100 眼神到位7分
#
# 226200 废话太多扑街都磨叽
#
# 226300 2015年之后还在推出这种电影就是对观众的不负责任
#
# 226400 剧情合格可结局有点出乎意料以为俩人以后能搭档接着做生意呢男主居然就轻松被干掉了女主真乃深藏不露的高手
#
# 226500 印度片拍得还不错比国产的强
#
# 226600 故弄玄虚
#
# 226700 恐怖青春爱情片
#
# 226800 男二差了一点
#
# 226900 剧情不连贯反派的配角好多特写镜头感觉和导演有什么故事一样主角太丑飞机起飞过程中就能开了舱门跳下去了200人起飞过程40秒能跳下去200多人么还有就是各种5毛特效千万别浪费时间
#
# 227000 地下停车场的故事
#
# 227100 剧情很傻女主角太漂亮了多加一星
#
# 227200 画面剧情表演都一言难尽还充斥着各种明晃晃的广告完全是浪费时间
#
# 227300 让爷乐一乐靠什么品位啊
#
# 227400 此片名字看似唯美陈宏一在开始却想叫做蜂蜜大便没错蜂蜜甜美大便恶臭二者反差极大其涵义将会在片中呈现周迅前男友台湾著名造型师李大齐在影片中出演角色他和陈宏一是相识十几年的老友彼此都很视觉系美感有余剧情散落摄影风格太强造成了故弄玄虚空有架势的影像操作而偏离了轨道
#
# 227500 18岁的叛逆和如何寻找自我剧终镜头很有创意
#
# 227600 导演水平不行
#
# 227700 虽然画面不够美但是没有猜到结尾要加分
#
# 227800 导演有想法但是没拍出来
#
# 227900 很喜欢剧中的吉冈老师
#
# 228000 音乐真的很棒
#
# 228100 情节无比拖沓那50个血牛去哪里170106
#
# 228200 吃翔都赶不上热乎的
#
# 228300 这次终于不玩百合大法了不过这个女主最坑爹女主你说你早一个一个帮她们把颈环给磨掉了大家不都能活了吗
#
# 228400 个人感觉这部改编看点不在推理在于内啥
#
# 228500 比漫画差远了无聊死
#
# 228600 不管是表演还是镜头调度在片中都是渐入佳境的导演手法还是可见一斑怪诞有趣很有调性跳舞大妈稚脸娃娃豹面男这些可可爱爱奇奇怪怪也友爱自在极了难能可贵的是干净凛冽不见粉饰的影片气质电影本来也是一件很私人的事就偏爱了5星
#
# 228700 强行支付
#
# 228800 还不错对那些音乐不能理解有个疑问后面男主回超市拿东西时看到的那个人是不是他的幻觉原来片中那些单词星期一到星期天星期一Montag星期二Dienstag星期三Mittwoch星期四Donnerstag星期五Freitag星期六Samstag星期天Sonntag
#
# 228900 影片许多方面都只浮于表面没有做透包括小女孩举枪的高潮都显得有些无力
#
# 229000 真不知道这算是什么
#
# 229100 居然有黄伟文
#
# 229200 郑中基那段学坏的片段太逗了
#
# 229300 基本上全部人我都很爱啊
#
# 229400 久远了
#
# 229500 这是要讲啥子一石二鸟嘛
#
# 229600 跟早期的港片不能比了
#
# 229700 中国香港
#
# 229800 浪费胶片
#
# 229900 笑林足球不好意思笑点在哪
#
# 230000 两个感情不错才能取得胜利
#
# 230100 风景不错
#
# 230200 也太假了吧当德军是猪啊
#
# 230300 孤女复仇记片尾有反转但是打戏太粗糙了
#
# 230400 男女主都不熟啊
#
# 230500 被Allocine上的观众评价误导还以为是thriller平实简单继父play狗血
#
# 230600 作为百年孤独作者加西亚马尔克斯的儿子导演罗德里格加西亚拍点深邃的片子也顺理成章不过这部由伊万麦克格雷格主演的耶稣故事通篇都是事实而非的对白让人完全摸不着头脑只能说这是专属于教徒们的影片吧6分
#
# 230700 8080中产阶级的都是一个样也许每天都在不停地走赶着每个宴会却永远不知道自己真正要的是什么浑浑噩噩地过日子还乐得其中
#
# 230800 可能是今年观影中最小资最文艺范儿的一部从中似乎可以窥探出法国新浪潮为何广受文青推崇闲散的调调导致没看进去多少除了珍茜宝很好看之外其余均无法确定
#
# 230900 世界是那么苍白
#
# 231000 还不错的喜剧片我感觉是喜剧片至少是故事性很强不过感觉里面的德军好仁慈
#
# 231100 老电影好啊老电影棒老电影呱呱叫
#
# 231200 很难想象是1930年拍的
#
# 231300 开场直接将双方对立树立起来剩下的时间就是来推演这种对立中间夹杂了酒鬼警长的自我救赎和女赌徒的感情戏份作为缓冲不过中间的缓冲也因为太久早就结尾的对战不够精彩约翰维恩一贯的正义形象没有任何妥协反倒是酒鬼和老警察更出彩
#
# 231400 和正午相似而又完全相反火车倒计时Vs监狱保卫战一个向外推一个向内吸加里库珀瘦削而紧张想要寻求帮助却无人施以援手约翰韦恩壮硕而悠闲不想牵涉他人反倒总有人主动帮忙色彩是黑白对彩色时长增一倍几次枪战和数个人物性格娱乐性极高福特定义西部片霍克斯定义神枪手
#
# 231500 前半直到驱使牛群过河为止都极好场面宏大壮观操控成百上千头活生生的牛按照需要奔跑半夜受惊和横渡红河两段即是经典之笔从撇开约翰韦恩便开始降了一档剧情走向顺利得不可思议缺乏敌人磨难面对几乎没有反面角色的情形硬是把正男主掰成反一号结尾就像是强凑出来的局面太奇怪了
#
# 231600 人物刻画女人的争斗
#
# 231700 AsignificantpostWWIIpaeanthathonestlyandsensitivelydepictswithasatiricalundertonethetraumaandobstructionsencounteredbyscarredveteransofdifferentsocialclasses
#
# 231800 因为其他人的婚姻多了些势力的色彩显得Homer和Wilma特别美好
#
# 231900 家庭情节剧Wearethepeople
#
# 232000 主题曲真好听
#
# 232100 62上映的卖座片不是电影专业的看起老片寡淡得很那么的人物中景烦透了
#
# 232200 偏执狂的胜利和失败
#
# 232300 在新闻炒作铺天盖地的今天新闻工作者们都应该去看看这部电影比利怀尔德那么早就已经讨论过这个话题了黑色电影中的黑色电影
#
# 232400 黑色幽默的极致在满足无尽的欲望的时候悲剧总是不远的
#
# 232500 我也要清醒了
#
# 232600 故事很有意思就等着人物怎么毁灭结果是个好结局重点是我还接受了
#
# 232700 经典中的经典老片也有很有魅力
#
# 232800 BradPitt就像年轻时候的RobertRedford还有PaulNewman实在是太有魅力啦完美结局
#
# 232900 结尾的雪中乱战精彩至极惨烈无比只此结尾就足可以列入经典武士片之列更何况本片并不是为了打而打桥本忍的剧本从头到位都设置了种种悬念故事内容饱满可以说本片不仅武戏经典文戏也同样出众若说有什么不足的地方可能应该就是片子稍微长了一些吧四星推荐
#
# 233000 开篇略散漫但渐入佳境重点段落都很精彩立意最后点出即无论做什么样的选择武士都无可避免地走向消亡很多场景很美冰与火的表现也很突出
#
# 233100 不大气却精致
#
# 233200 结尾有点杜琪峰的味道
#
# 233300 五社英雄拍男女之情爱甚至比他的剑侠部分更动人老刘和美雪现实中在一起了吗
#
# 233400 很B级很cult
#
# 233500 如果真的是悲剧结尾的话这部电影将更加经典
#
# 233600 这么主旋律
#
# 233700 最后保留了一片光明从而对现实黑暗的批判少了许多而且面对黑暗的现实树立了红胡子这样一个楷模也有说教的意味
#
# 233800 又是带有冈本喜八浓烈风格的杰作啊
#
# 233900 插叙大王
#
# 234000 沟口健二成精了
#
# 234100 极具现实意义的超现实故事唯美的画面
#
# 234200 本子可以黑泽明很会结合时代背景虽然电影本身并不十分出彩以40年代的电影发展来说也算有才了
#
# 234300 导演最近刚刚过世没多久想重温一下还没找到时间
#
# 234400 红旗颂长城尸
#
# 234500 史诗片要拍成这样才叫史诗片布列斯特要塞一直在坚持
#
# 234600 很难得连战争片我都看不下去了
#
# 234700 虎头蛇尾的最后结局有点仓促了总体还是不错的
#
# 234800 那一段永远也无法忘却的记忆
#
# 234900 伊斯特伍德的电影总感觉不给力
#
# 235000 摄影极烂
#
# 235100 大场面在历史上是赫赫有名的滑铁卢战役拿破仑与惠灵顿都是留名青史的人物他们之间的碰撞战争总是很残酷的看着那么多人一排排的倒下去心里很不是滋味越来越反感战争但是战争必然有胜利者和失败者结果是很多因素决定的这部电影场面很大但是没有把滑铁卢战役的来龙去脉交代清楚
#
# 235200 TheycarriedthesamebibletheybelievedinthesameGod
#
# 235300 活着还是有意义的活着
#
# 235400 很有意义的一部电影
#
# 235500 关于战争的温馨解读
#
# 235600 少有的一部深刻反省的中国史诗电影出自一位意大利导演之手何其悲哀我们自己在干什么在遗忘另外在电影里看见自己的家乡抚顺还是比较难得的
#
# 235700 史诗巨作联想到霸王别姬
#
# 235800 列宁的雕像从窗外掠过我们以为的大部分不是事实
#
# 235900 现实的片子很压抑
#
# 236000 事实残暴毁字繁复任何人能做任何事某些时候便尤为罪孽深重惨案之后还是惨案没法了
#
# 236100 如一
#
# 236200 宗教洗脑
#
# 236300 维斯康帝拍得这堆文学改编片叫人胆寒
#
# 236400 雪子就是紧紧地抓住回忆到死也不肯松手
#
# 236500 8偷窥不免想起了后窗
#
# 236600 很可惜我没有看到260的完整版本而是140的剪辑版但即便如此也并不影响这片子带给我的强烈震感虽然四个多小时的叙述更使人荡气回肠老库这回把焦点放在了一个世界性的民族之上吉普赛人罗姆人描绘了在时代变迁中的他们生存现实的概况流浪的本性与浪漫主义人格使人笑中带泪
#
# 236700 前半段简直是灾难后面才有点味道
#
# 236800 monicavitti真美
#
# 236900 刚看完没觉得和神有关联现在觉得确实和神有联系神之沉默三部曲之终结
#
# 237000 186
#
# 237100 姐喜欢这个范儿
#
# 237200 KeyWords1凯尔特音乐2蝴蝶夫人咏叹调3以暴制暴4没有女主角5虔诚者的杀戮6246次fxxk7型男兄弟妙探教父代表上帝惩罚你
#
# 237300 最爱这种片
#
# 237400 也许我是个杂种但不是狗杂种
#
# 237500 热血了一会就淡定了
#
# 237600 我也经常怒火攻心withoutdrug当街圈圈叉叉这事儿忒狂了可是为什么要发生在唐人街最后从飞机上坠落明显很假但最后那段话真的蛮动人的老实说我喜欢高潮发生在结尾感人直接然后立刻结束这样才能让我记得很久20096302009630
#
# 237700 我喜欢这调调
#
# 237800 北野武一直都蛮喜欢意淫他自己的我蛮喜欢日本时代剧里面的暴力效果加入了很多3D成分那血涌的很有动漫感
#
# 237900 北野武门下走狗
#
# 238000 门下走狗
#
# 238100 开场的音乐便与众不同几十秒后出现埃尼奥的大名繁华都市里西部牛仔扛起长枪威风凛凛不再执着于法规的条条框框你们太暴力了扫地神僧被刺杀浴血爬行交叉切换的画面德尼罗听歌剧留出悲伤的眼泪我从未对你如此恨之入骨啊罗伯特车站一战紧张气氛轻而易举笼罩整个镜头经典至极
#
# 238200 对光线和镜头的运用别有匠心缓慢却不冗长的剧情刻画了别样的父子之情
#
# 238300 为什么JudeLaw在TomHanks面前黯然失色
#
# 238400 想到了许多自己国家的事情
#
# 238500 美国的兴起也是在市井之间而这里面掺着着太多难以用善恶好坏来表述的东西
#
# 238600 结尾可是太失败了古惑仔收官之作实属败笔
#
# 238700 喜欢山鸡才看的哈哈
#
# 238800 用荷尔蒙和肾上腺毁了多少有志青年
#
# 238900 我叫山鸡78的7
#
# 239000 我不知道阿乐临死有没有把我当兄弟可是他是我唯一的兄弟
#
# 239100 年轻时候的梦想就是像陈浩南一样做老大有山鸡包皮大天二这样的兄弟
#
# 239200 古惑仔系列统一4星
#
# 239300 一直不承认这是古惑仔的终极篇
#
# 239400 又名Sangoowaakchaijisiuningikdaupin导演刘伟强WaiKeungLau上映年度1998制片国家地区香港imdb链接tt0168264
#
# 239500 算半记录片
#
# 239600 吴宇森式枪战
#
# 239700 terribletrip
#
# 239800 因为爱情一段英雄的江湖传奇
#
# 239900 第一次叶童让我觉得她不是个男人
#
# 240000 火车电影NO1典型的吴宇森式暴力美学可惜后面让人暴力得让我觉得难受哪怕是好人杀坏人的时候这部片子中关于三个朋友人性变化的描写倒是值得学习PS学友哥哥演戏真的好用力呀
#
# 240100 喜欢梁朝伟在喋血街头里为一歌女顶撞大佬的片段喜欢黑金里梁家辉开会那段谁赞成谁反对喜欢新上海滩中许文强这个角色喜欢的太多了我喜欢电影这种语言它让我喜让我悲让我思考让我震撼
#
# 240200 很难得的黑色幽默经典
#
# 240300 六星
#
# 240400 学好英语击败黑道
#
# 240500 朋友力赞的影片确实不错帮会的个别组织势力太大了帮会的老大要解决一部分人来平衡一下帮会的老二一直看着老大在最后来了个螳螂捕蝉黄雀在后把老大解决但是实际上这是一个复仇的故事石原一个被灭掉的组织的成员为了复仇打入敌人内部报仇成功影片紧凑没有一丝多余的空隙
#
# 240600 人生有三碗面最難食就是人面場面情面
#
# 240700 一对死宅废柴基友与一个抽烟喝酒说脏话没有节操的外星人逃亡路上与电波族黑暗系公务员斗智斗勇的故事
#
# 240800 叙事好流畅
#
# 240900 无聊
#
# 241000 妓女的香港进化史
#
# 241100 相戀請按2字
#
# 241200 如果爱上一个女人就别管她精神有没有问题因为爱上一个人时精神已经是有问题了
#
# 241300 突然想到以前非主流语录里有一句青春是糖甜到忧伤看样子是出自这电影了
#
# 241400 笑死爹
#
# 241500 自从僵尸肖恩开始这种血腥喜剧越来越多但好在质量普遍还不错比绝大多数的屎尿屁喜剧有意思的多乡巴佬血战脑残这个译名真心切题
#
# 241600 憨豆撞正女杀手这名字超赞
#
# 241700 影响家庭幸福了肿么办老太太微微笑一下然后杀掉你
#
# 241800 模式继续延续第一部但是没有第一部那种信手拈来的巧妙全片依旧布满了笑点和大丈夫们的疯狂行径全片三个亮点非常不错胖子在佛堂回忆的时候他们变成小孩的样子小孩好像他们好可爱啊结合泰国国情去酒吧找人妖问话猴子在屋顶抽寂寞的表情期待第三部胖子结婚一伙人继续去ha
#
# 241900 加强怪咖版的午夜狂奔一般吧
#
# 242000 萝卜真有范儿与生俱来的
#
# 242100 前面对话类节目太久了后面还是挺恶搞的
#
# 242200 我是来检讨的居然现在才看
#
# 242300 好喜欢Marvin抑郁症的机器人冷笑话不断
#
# 242400 装神弄鬼
#
# 242500 结构比盗梦空间复杂得多钱少得多有趣得多
#
# 242600 五顆星和三顆星就在一念間
#
# 242700 7378
#
# 242800 像马克吐温的小说130
#
# 242900 结尾有点潦草
#
# 243000 很能搞语言很强其他一般
#
# 243100 扎实
#
# 243200 这部就是之一
#
# 243300 拍得真美
#
# 243400 黑色幽默法式幽默
#
# 243500 无厘头鼻祖
#
# 243600 不列颠人是没有节操的
#
# 243700 居然吃了那么多可爱的热带鱼
#
# 243800 离家不远的电影院在放映塔蒂的特展纯胶卷的我想法国式的幽默有什么好笑所以经过也不回头后来不久电影院就关闭了我也再没有机会进去所以看到塔蒂喜剧我想起的会是这样一段关于无知愚蠢的记忆
#
# 243900 从安妮霍尔开始伍迪艾伦与有Princeofdarkness的GordonWillies合作包括InteriorManhattanSummermidnightcomedy等进入21世纪伍迪的作品黑色影调渐少特别是欧洲三部曲近乎刺眼2004年Gordon去世
#
# 244000 伪纪录片的叙事风格天马行空的故事与创意对社会的思考黑色幽默依旧的话唠和爱情故事有趣又奇幻
#
# 244100 早期恶搞作品
#
# 244200 永远喜感的小老头
#
# 244300 这个小老头很有意思
#
# 244400 淳朴的怀旧风
#
# 244500 这部片子大概有一半是虚构的另一半是真的他的实验电影在美国差评满天itstrue他跟中国摄影师赵非无法沟通itsnottrue
#
# 244600 编剧之神请赐我WA的想象力
#
# 244700
#
# 244800 伍迪艾伦自我吐槽的片子玩结构有些过头不仔细看就会无聊片中片的结局精致浪漫可如果试着回忆这美好自然结尾的缘起我却想不出任何一个暗示性的情节
#
# 244900 差到点里那么难看的
#
# 245000 淡淡的
#
# 245100 赫本时装秀惊艳啊
#
# 245200 不一样的赫本
#
# 245300 呃不怎么好
#
# 245400 西方视角下的爱情婚姻观以及赫本的换装秀
#
# 245500 如果有一天我真心的说我爱你就像一位骄傲的将军向他的敌人交出了宝剑
#
# 245600 对得起经典
#
# 245700 经典之作
#
# 245800 嘎嘎
#
# 245900 好早以前看的
#
# 246000 看这种片子我总是忍不住心里难受总是忍不住泪流满面亲情是无价的
#
# 246100 从一开始就告诉大家在办葬礼偏有人想要什么鸡吧亲情有亲爱情要什么鸡吧父女的互动
#
# 246200 开头很搞后面变悲剧了囧一个
#
# 246300 还行
#
# 246400 喜欢主题曲经典
#
# 246500 马马虎虎
#
# 246600 不是被删减过的就好了
#
# 246700 章子怡是真的会演戏的怎么就没人信剧情那么苍白无力我都能看出感觉来除了演技别无他想
#
# 246800 開高走低聲音最好麻將也不錯老男女的愛情不走爭風吃醋反而出乎意料溫馨玩具還算有一點趣味但沒收好剩下兩個就蠻不怎樣
#
# 246900 只想说在中国最难看到的就是中国电影独立电影遍寻无果老电影黑乎乎一片环境声吵杂就没人修复打理吗
#
# 247000 那许久未见的高山
#
# 247100 一颦一笑千金重黑白光影听惊雷此生可待成追忆监牢窗前思华年悲情神女阮玲玉人言可畏消玉殒
#
# 247200 默片太考验演技了节奏稍微慢了点
#
# 247300 长亭外古道边芳草碧连天
#
# 247400 狂热的迷恋需以死句读贝尼诺的缺席或许这才是最好的结局PS西班牙女人真是美得让人窒息影片丰富的内涵与哲学层次让人回味不愧大师级作品
#
# 247500 像烟花那样绽放
#
# 247600 小牙缝女如今已经长成了真爱如血里面的大牙缝女
#
# 247700 我只觉得赢在视觉构图
#
# 247800 陈冲
#
# 247900 美景啊美景真心国产电影里的经典
#
# 248000 那个时代能够影射的东西太多最精彩的应该就是总以为是结局了吧却还是设想的一种可能罢了我想结局是他们不会再遇到因为那是偿还十年动乱的代价
#
# 248100 这个乔安真是伟大
#
# 248200 那时候董洁还是个小萝莉现在已然为人母了
#
# 248300 我还是很喜欢董洁这个女演员的
#
# 248400 一只乌鸦口渴了想找水喝感动于巩俐的敬业
# 248500 这是一系列悲惨的事件所有死亡仇恨之外的声音都很微弱虽然试图在结尾展现生的希望但从头到尾的态度却异常绝望甚至可以说在很多时候死亡才是最好的归宿难道说历史告诫我们的就是死亡比活着更好么电影中的这个声音太强大压过了所有其他的东西
#
# 248600 整个一部预告片
#
# 248700 接近四星经典题材但没吹那么强煽情做作杀手大傻子般送死不一拥而上情感烘托和小谢表演是亮点
#
# 248800 vcd姥姥家
#
# 248900 姜文送走弟弟妹妹的时候肠子都哭断了
#
# 249000 本片之后陈导开始走下坡路
#
# 249100 还满温馨的
#
# 249200 有失水准
#
# 249300 该有的都有了张扬为突破平庸做了不少努力
#
# 249400 荒诞得有趣
#
# 249500 东木电影视听语言简直可以用呆板来形容了电视水准
#
# 249600 7010分偏向写实风格毕竟是真人改编
#
# 249700 儿童版拆弹部队逼迫二战德军孩子战俘排地雷渺小脆弱生命挨个被炸惨死加上喜怒无常丹麦军官冷峻压抑绝境氛围绷得悬念紧紧的欧洲编导擅长对话少利用镜头语言叙事浓烈的反战与悲天悯人视角战争仇恨不应延续所以宽恕化解恩怨反如释重负
#
# 249800 虽然太正能量鸡汤了一点但是还是受到了深深的震撼尤其前面练习拆雷和后面每次知道有人要被炸时看得紧张可以结合我们的父辈一起看
#
# 249900 短片下一层导演维伦纽瓦摄影罗杰狄金斯结局掐得恰到好处
#
# 250000 追捕的时候躲桌子下访客证在地上捡到这种关键细节编得太水了吧跟一般间谍片差不多墙上的FightClub海报有暗示最后的反转也不过学非常嫌疑人并没有很有趣啊
#
# 250100 粗俗的剧本廉价的趣味
#
# 250200 小浪漫好音乐女朋友最爱
#
# 250300 电影拍的有点失望有钱真好啊我也想逆袭TT
#
# 250400 其实我一开始没看懂哈哈
#
# 250500 主题曲太好听为什么这么多导演客串
#
# 250600 阳光沙滩阿菲哥哥啊标准的偶像剧啊话说大结局可真TM和谐圆满啊
#
# 250700 变态心里暧昧挣扎抉择最有感觉的还是开始过一段后那永无止境无限延伸的房间与灯笼
#
# 250800 第一次看是大二大三的时候之后又看过无数遍心里有种莫名的喜欢和甜蜜蜜一道是我最钟爱的华语电影
#
# 250900 影片最后感动到我了
#
# 251000 过去让它过去来不及
#
# 251100 老套至极的故事最大的收获是知道从前华仔的演技也没算糟糕
#
# 251200 中午又重温了张婉婷的移民三部曲这个架构在麦琪礼物故事上的电影透露的却是异乡漂泊和苦中作乐的温馨这是张婉婷擅长的唯美刻画的大时代的小人物每每总能打动我
#
# 251300 红姑很有味道
#
# 251400 开头以为是鬼片呢看到最后发现不过一句人生若只如初见
#
# 251500 真是越来越看不得丑恶的人生
#
# 251600 挺乱的很明显没有巴黎我爱你那么惊艳文艺倒是挺文艺的就是文艺得有点儿无聊了真的很一般
#
# 251700 祝英台不够漂亮
#
# 251800 很俗套的故事但是不讨厌
#
# 251900 眼泪忍不住的
#
# 252000 你为什么不相信我
#
# 252100 从前和以后一夜间拥有难道这不算相恋到白头
#
# 252200 结局好狗血整个片子就是大狗血开头惊悚气氛还蛮足的后面拍懒了
#
# 252300 看得不是电影是人听得是歌
#
# 252400 哥哥的歌很好听
#
# 252500 对我来说有一件事情是永远不会忘记的这个有着长长的双辫子红红的脸颊水灵灵的大眼睛的女孩在我的记忆中一点也没有改变过今后也永远不会改变
#
# 252600 两位姑娘真可爱虽然不太分得清她们俩谁是谁这些关于旅行成长梦想和友情的点点滴滴即使旅途中充满坎坷和艰辛那些曾经一起奋斗的经历也都是我们最美好的回忆还好有过争执有过分歧有过别离你们也始终没有放开彼此的手
#
# 252700 泰国小正太帅瞎眼呀
#
# 252800 主题曲秒杀
#
# 252900 他要证明爱能赋予自己勇气她也接受一份下午3点以后才出现的爱
#
# 253000 喜欢听那孩子讲日语淡淡惆怅晾凉了却微微温热的话语她让你不要有负担可是你终究忘不了那份柔软的牵挂
#
# 253100 自然卷永远都拉不直
#
# 253200 主创一定有很多美好的青春回忆也很可能像贾樟柯拍站台那种还愿式的急迫心情遗憾的是导演把这些青春碎片电影化的能力太弱线索庞杂想表达的太多缺少凝聚力单场戏的张力也不够很多可以着力做细的点都没展开细节都伏在表面哎妈白瞎了这么多点人生各个阶段被抓住的无奈和美好哟
#
# 253300 台湾也拍了此类68青春电影总是让里面的嗲角色显得很不着调
#
# 253400 不喜欢钮导平铺直叙的表达方式
#
# 253500 一只因家庭问题衍生的问题萝莉推倒问题正太的剧情片
#
# 253600 租的碟学校机房看的连着看了三遍
#
# 253700 徐静蕾的片子总是那么多旁白
#
# 253800 知识改变命运
#
# 253900 文艺片
#
# 254000 好蠢v
#
# 254100 年轻人可以有所借鉴
#
# 254200 不能欣赏其中的原创音乐倒还可以
#
# 254300 年轻就是不惧一切勇敢追求
#
# 254400 DontletthedreamerdienomatterwhatlifethrowsatyounomatterwhereyouareandwhoyouwillbecomedontletthedreamerinsideyoudieDontletthedancedie
#
# 254500 女主角看上去挺可爱其实有点缺心眼如果拍成彩色的会逊色不少吧
#
# 254600 土耳其五姐妹的情事婚事死亡醒悟反抗题材占优故事流水结局淡漠虚幻摄影赞五姐妹鲜活的少女气息很足也过足了忽视了剧情节奏和细节整体残酷不尽人意控诉和抗争都很苍白
#
# 254700 原来还有这么封建的地方我要提亲
#
# 254800 净是些我讨厌的点看了接吻再看这里的丰川感觉好怪而且故事性不强有一点文艺性但是也不强说是喜剧完全不觉得好笑只能算是热血老师励志片然而这种片子我已经看得审美疲劳了
#
# 254900 清新的小镇蔚蓝的海恬淡的生活生活在岛上的怪怪的可爱的人们你没办法不喜欢比婆婆这个会做好吃的菜的总是穿的很青春的不管60岁还是70岁或者80岁都保持着20岁少女心态的可爱老人
#
# 255000 为什么没有大叔和阿久在一起的情节
#
# 255100 记忆中的夏天理想中的青春抑制不住的感动
#
# 255200 爱摄影爱小葵
#
# 255300 宫崎葵太可爱了玉木宏在里面更像toma同学
#
# 255400 片子受欢迎的原因很大一部分要归功于清纯可人的长泽正美正当花季的少女本色演出是件何其撩人的事而最终为了剧情削发为尼的敬业精神也让她一夜成名可惜结尾的成人戏再度不负众望地落入纯爱片矫情造作的俗套其实电影本身很多地方就没逻辑因此原本就并不强烈的好感更坚定了我3星的评价
#
# 255500 老娘不曾拥有过的青春啊闪耀夺目光芒的青春呀_两个小孩真是大大抚慰了我苍老滴心TT就让我回归一次不现实吧
#
# 255600 是不是青春电影都要镜头晃啊晃的
#
# 255700 这个被遗弃的可怜的孩子他的世界实在是太纯洁了
#
# 255800 傑作真正重要的東西是肉眼看不見的
#
# 255900 因为我梦想那不是真实的我
#
# 256000 淡淡的却很深情政治恩怨让位于挚爱亲情小男孩的表现非常好用莲蓬头打电话那段又可爱又可怜
#
# 256100 不停奔跑的正太拯救这疯狂的世界
#
# 256200 童年的孤独表达真不错
#
# 256300 呃觉得不如闲人和危城虽然差不多时代而且甚至环境布景道具都精致了很多感觉故事有点散和刻意猜想是不是原著内容太少了要扩充出来比较难呢当然整体还是很顺畅的演员虽然感觉穿越但也算表演得蛮投入了尤其是MS朱和胖姑娘都演得特别到位男主毫无内心戏对他的刻画太刻板了
#
# 256400 那是一个更纯真和美好的年代真喜欢那时候的少女身上那种饱满而天真的美光洁的肌肤圆润的面孔清澈的眼睛比现在的锥子脸不知道美多少
#
# 256500 他们愿唱着有国家名字的歌儿
#
# 256600 恕我愚昧在这部电影之前我没有注意过这样一个导演和黄蜀芹人鬼情的女性叙事一样这部女性电影也足以跻身华语类型电影里的一个高度巧合的是大陆的人鬼情和这部力作差不多在同时上映女性的觉醒的确是关注现代转型的一个有趣着力点当然在母亲节我看的不仅仅是电影而是我的妈妈
#
# 256700 三星半还不错
#
# 256800 79年的电影140多分钟英语字幕我竟然没有快进的看完了第一次看到薰姨的小女生样哎你年轻时真的不漂亮呀但怎么那么动人呢最后那几封未拆的信真让人难过归根结底那个人你不爱所以他做什么都只能是多余
#
# 256900 只有音乐让人惊艳森迫永依大萌神大东俊介雷死我了
#
# 257000 看不懂的好电影暗恋是不会有结果的李灿森也有不是潮男的时候
#
# 257100 比起九将风烈日当空有种初生牛犊不怕虎的大胆在里面
#
# 257200 最后那首歌真好听我不知道该不该给五星咖啡店的那个故事是太无聊还是其实我没看懂字幕
#
# 257300 法国乡下美古朴院子到处是夹竹桃法国梧桐印度榕远处群山起伏田野满目葡萄适宜人居中年妇女作多愁善感疑心病恋爱中的寡妇也会像少女一样回到心跳的纯情胶片就是胶片质感忒迷人蓝光修复极好
#
# 257400 大一的时候看相当地郁闷看第二遍居然有种震动
#
# 257500 非常纯粹非常孤独的电影时代美术馆
#
# 257600 从开始给5星了不再吝啬
#
# 257700 有些东西没办法说
#
# 257800 美好的东西有什么意义以前能持续一辈子现在只能持续几天最后一段闷死但又像极了人无法满足的渴求最终如孤岛一样被包围的海浪淹没窒息失踪女人的下落真的不重要不过是个线索西西里的男人是不是一辈子没见过漂亮女人结尾意蕴悠长第一部安东尼奥尼
#
# 257900 如此准确
#
# 258000 很浪漫一看就是年轻人的作品在水中看到爱人的场景充满诗意拥抱可以一直到倒在地上说实在的里面每个男性角色都比男主角好暴力大男子主义还是个醋坛子最后还是老水手把老婆找了回来真不知道女主角爱他哪一点
#
# 258100 三部曲看到这最后一部以为妙绝
#
# 258200 只有神经病的大人才不会说谎
#
# 258300 西門町的故事
#
# 258400 很一般可以看
#
# 258500 挺好一剧可惜镜头太长
#
# 258600 这是爱的表达
#
# 258700 技术非常好
#
# 258800 绝对是青春片中的经典之作
#
# 258900 绿得真美直让我想去日本乡下过一段时间
#
# 259000 盲女寮跟自梳女好像这次的筱田正浩挺正儿八经的卡司好强喜欢阿玲对情欲和人生的态度觉得很诚实
#
# 259100 电影里的背景声音太有意思了还有几段梦境特别喜欢夜晚谈话那段很奇妙又催眠的感觉锡兰牛的地方是把普通的东西拍出了有意思
#
# 259200 人的贫穷会造成信仰的缺失然后就可以看到女主信谁就被谁上被谁欺骗被谁抛弃
#
# 259300 只是觉得这场枪战是真实的还是如果呢
#
# 259400 小镇
#
# 259500 且看浪漫之都青少年如何面对性成长有着教室别恋的少年懵懂和渴望夹杂着政治大环境下的微妙家庭关系还有着西西里美丽传说的家庭政治因素结局一家人哈哈大笑不知道的幻想着那晚知情者仿若昨晚事情没有过一切都很美好只是情节上有些拖沓
#
# 259600 另类是不够的01012017atMoMI
#
# 259700 没能坚持看完中途睡着3次类似电影看过很多都喜欢可是这个镜头语言没语言整体结构没结构还拍那么长喂你实验个屁啦
#
# 259800 还真的挺不错的各种的来围观一下吧
#
# 259900 当你不想解开时也便成了死结当然会有释然的一天待命运去安排表面上讲的不外乎那纠缠万世的纳粹与犹太实质上还是回归人性根源从思想心智上去雕琢这一故事值得肯定不过时代穿插得太凌乱太突然对注意力的需求较苛刻
#
# 260000 贫贱家庭百事哀
#
# 260100 IanCurtis死前看的一部电影学主人公自戕了
#
# 260200 劳动人民也都是有着美丽梦想的
#
# 260300 放下幻想
#
# 260400 琐碎简单直接的生活细节下面凝聚着一股透彻至骨髓的情感早期还没有内心爆裂式拧巴的皮亚拉其实更有深沉的力量这也是我看过的最举重若轻的银幕死亡描述画面构图和光线造型在简约中完美至臻
#
# 260500 纯纯的淡淡的一切那么美好我在等待那个飞鱼季
#
# 260600 漂亮姑娘在抽烟剧情可忽略
#
# 260700 姑娘纯白
#
# 260800 其实是因为蔡健雅的MTV才看这部电影的
#
# 260900 故事还蛮烂的很台湾的青春电影感觉还不错青春充满了残酷彷徨冲动与坚强有如刚刚升起的太阳热烈夺目而又使世界蒙上一层光晕琢磨不定影片中大段大段的长镜头手持拍摄和近景拍摄虽有些感觉但总体太过刻意太过粗糙和太过重复
#
# 261000 拍电影拍成mtv简直就是浪费胶片实在够烂
#
# 261100 窮斃的小演員們表現尷尬對白生硬故作幽默自以為很懂年輕人除了攝影和音樂尚佳近年電影裡難得呈現詩意的台北我想問這位潛伏多年復出的導演你就只會這招嗎
#
# 261200 爱上一个人是件开心的事节奏再快点不要拖沓就好了
#
# 261300 没什么剧情没什么渲染就是那么平平淡淡最后秘密的柏拉图爱情终于实现了
#
# 261400 被标题骗来的觉得不怎么好看

# %%
TOKEN[40]
# Out:
# '物理'

# %%
from collections import Counter

# %%
words_count = Counter(TOKEN)

# %%
TOKEN = [str(t) for t in TOKEN]

# %%
TOKEN_2_GRAM = [''.join(TOKEN[i:i+2]) for i in range(len(TOKEN[:-2]))]

# %%
words_count_2 = Counter(TOKEN_2_GRAM)

# %%
def prob_1(word):
    return words_count[word] / len(TOKEN)

# %%
prob_1("我")
# Out:
# 0.010593437027153863

# %%
def prob_2(word1, word2):
    if word1 + word2 in words_count_2: return words_count_2[word1+word2] / len(TOKEN_2_GRAM)
    else:
        return 1 / len(TOKEN_2_GRAM)

# %%
prob_2("我","你")
# Out:
# 7.786509892655596e-06

# %%
family_num  = '''
family_num = 称呼 短语 玩具 程度副词 名词 结尾
称呼 = 宝宝 | 妮妮
短语 = 你买的 | 你的
玩具 = 芭比娃娃 | 小猪佩奇 | 毛绒小熊
程度副词 = 程度副词 | 程度副词 程度副词 
程度副词 = 太 | 有 
名词 = 多 | 不少
结尾 = 了啊 | 了啦 | 了哦 | 了呀
'''

# %%
def create_grammar(grammar_str, split='=>', line_split='\n'):
    grammar = {}
    for line in grammar_str.split(line_split):
        if not line.strip(): continue
        exp, stmt = line.split(split)
        grammar[exp.strip()] = [s.split() for s in stmt.split('|')]
    return grammar

# %%
import random
choice = random.choice

def generate(gram, target):
    if target not in gram: return target # means target is a terminal expression，终止符
    
    expaned = [generate(gram, t) for t in choice(gram[target])] #将非终止的target扩展
    return ''.join([e if e != '/n' else '\n' for e in expaned if e != 'null']) #合并，舍去 null

# %%
example_grammar = create_grammar(family_num, split= "=")

# %%
def get_probablity(sentence):
    words = cut(sentence)
    
    sentence_pro = 1
    
    for i, word in enumerate(words[:-1]):
        next_ = words[i+1]
        
        probability = prob_2(word, next_)
        
        sentence_pro *= probability
    
    return sentence_pro

# %%
for sen in [generate(gram=example_grammar, target= "family_num") for i in range(20)]:
    print('sentence: {} with Prb: {}'.format(sen, get_probablity(sen)))
# Out:
# sentence: 宝宝你的小猪佩奇太多了呀 with Prb: 1.9456582566050735e-39
# sentence: 宝宝你买的毛绒小熊太多了啦 with Prb: 2.815863036182066e-47
# sentence: 妮妮你的小猪佩奇太多了哦 with Prb: 1.888433013763748e-39
# sentence: 宝宝你买的毛绒小熊有多了呀 with Prb: 1.787062208264594e-50
# sentence: 妮妮你的芭比娃娃有不少了啦 with Prb: 5.36926845813131e-40
# sentence: 妮妮你的小猪佩奇太不少了啊 with Prb: 1.634120162134538e-46
# sentence: 妮妮你买的芭比娃娃太不少了呀 with Prb: 7.581169712797869e-49
# sentence: 宝宝你的毛绒小熊太多了啦 with Prb: 2.432072820756342e-40
# sentence: 宝宝你买的小猪佩奇有不少了啦 with Prb: 1.0466010688132609e-52
# sentence: 妮妮你买的毛绒小熊太不少了哦 with Prb: 1.5485040921286585e-55
# sentence: 宝宝你买的小猪佩奇太不少了啊 with Prb: 1.8919904543826519e-53
# sentence: 妮妮你的毛绒小熊有多了哦 with Prb: 1.4980963333323697e-43
# sentence: 妮妮你买的毛绒小熊有多了呀 with Prb: 1.787062208264594e-50
# sentence: 妮妮你的小猪佩奇有不少了啊 with Prb: 1.3399785329503214e-44
# sentence: 妮妮你的芭比娃娃太多了啦 with Prb: 1.1556743086252552e-33
# sentence: 宝宝你的毛绒小熊太不少了哦 with Prb: 1.3374495374613034e-48
# sentence: 妮妮你的毛绒小熊太不少了呀 with Prb: 1.377978311323767e-48
# sentence: 妮妮你的毛绒小熊有不少了呀 with Prb: 1.1299422152854892e-46
# sentence: 妮妮你买的小猪佩奇有多了啦 with Prb: 1.4296497666116751e-49
# sentence: 宝宝你买的芭比娃娃太不少了呀 with Prb: 7.581169712797869e-49

# %%
example_grammar = create_grammar(family_num, split= "=")

# %% [markdown]
# #### 3. 获得最优质的的语言

# %% [markdown]
# 当我们能够生成随机的语言并且能判断之后，我们就可以生成更加合理的语言了。请定义 generate_best 函数，该函数输入一个语法 + 语言模型，能够生成**n**个句子，并能选择一个最合理的句子:

# %% [markdown]
# 提示，要实现这个函数，你需要Python的sorted函数

# %%
sorted([1, 3, 5, 2])
# Out:
# [1, 2, 3, 5]

# %% [markdown]
# 这个函数接受一个参数key，这个参数接受一个函数作为输入，例如

# %%
sorted([(2, 5), (1, 4), (5, 0), (4, 4)], key=lambda x: x[0])
# Out:
# [(1, 4), (2, 5), (4, 4), (5, 0)]

# %% [markdown]
# 能够让list按照第0个元素进行排序.

# %%
sorted([(2, 5), (1, 4), (5, 0), (4, 4)], key=lambda x: x[1])

# %% [markdown]
# 能够让list按照第1个元素进行排序.

# %%
sorted([(2, 5), (1, 4), (5, 0), (4, 4)], key=lambda x: x[1], reverse=True)

# %% [markdown]
# 能够让list按照第1个元素进行排序, 但是是递减的顺序。

# %% [markdown]
# >

# %%
def generate_best(grammar_num, target, n): 
    example_grammar = create_grammar(grammar_num, split= "=")
    ss = []
    for i in range(n):
        gene_n = generate(example_grammar, target)
        s = [(gene_n, get_probablity(gene_n))]
        ss= s + ss  
        sort = sorted(ss, key=lambda x: x[1],reverse=True)
    return (sort[0])

# %%
generate_best(grammar_num=family_num, target="family_num", n=8)
# Out:
# ('妮妮你的芭比娃娃有多了呀', 7.334383297302435e-37)

# %% [markdown]
# 好了，现在我们实现了自己的第一个AI模型，这个模型能够生成比较接近于人类的语言。

# %% [markdown]
# >

# %% [markdown]
# Q: 这个模型有什么问题？ 你准备如何提升？

# %% [raw]
# Ans:语言还是不太准确；扩大数据库，2-grammar可能还需要扩展到3-grammar，4-grammar......

# %% [markdown]
# >

# %% [markdown]
# ##### 以下内容为可选部分，对于绝大多数同学，能完成以上的项目已经很优秀了，下边的内容如果你还有精力可以试试，但不是必须的。

# %% [markdown]
# #### 4. (Optional) 完成基于Pattern Match的语句问答
# > 我们的GitHub仓库中，有一个assignment-01-optional-pattern-match，这个难度较大，感兴趣的同学可以挑战一下。

# %% [markdown]
# #### 5. (Optional) 完成阿兰图灵机器智能原始论文的阅读
# 1. 请阅读阿兰图灵关于机器智能的原始论文：https://github.com/Computing-Intelligence/References/blob/master/AI%20%26%20Machine%20Learning/Computer%20Machinery%20and%20Intelligence.pdf
# 2. 并按照GitHub仓库中的论文阅读模板，填写完毕后发送给我: mqgao@kaikeba.com 谢谢

# %% [markdown]
# >

# %% [markdown]
# 各位同学，我们已经完成了自己的第一个AI模型，大家对人工智能可能已经有了一些感觉，人工智能的核心就是，我们如何设计一个模型、程序，在外部的输入变化的时候，我们的程序不变，依然能够解决问题。人工智能是一个很大的领域，目前大家所熟知的深度学习只是其中一小部分，之后也肯定会有更多的方法提出来，但是大家知道人工智能的目标，就知道了之后进步的方向。

# %% [markdown]
# 然后，希望大家对AI不要有恐惧感，这个并不难，大家加油！

# %% [markdown]
# >

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1561828422005&di=48d19c16afb6acc9180183a6116088ac&imgtype=0&src=http%3A%2F%2Fb-ssl.duitang.com%2Fuploads%2Fitem%2F201807%2F28%2F20180728150843_BECNF.thumb.224_0.jpeg)
